# %% [markdown]
# # LSTM Prediction ans Simple Trading

# %% [markdown]
# # Table of Contents
#
# - [Problem Definition](#Problem-Definition)
# - [Dataset](#Dataset)
# - [Feature Engineering](#Feature-Engineering)
# - [Status](#Status)
# - [Installation](#Installation)
# 	- [Docker Installation](#Docker-Installation)
# 	- [Prerequisites](#Prerequisites)
# 	- [Dependencies](#Dependencies)
# - [Contributions](#Contributions)
# 	- [Citing FinRL](#Citing-FinRL)
# 	- [Call for Contributions](#Call-for-Contributions)
# - [LICENSE](#LICENSE)

# %% [markdown]
# ## Problem Definition

# %% [markdown]
# The project target is to use machine learning method to investigate the applying possibility of market trading.
#
# In LSTM Prediction and Simple Trading subproject, here we discuss a simple approach use general Deep Learning method to predict market and apply the prediction result to a simple trading strategy to evaluate the portfolio performance.

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import datetime
from pprint import pprint
import itertools
import seaborn as sns
import tkinter
from sklearn.preprocessing import MinMaxScaler
from sklearn.utils import shuffle
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from tf.keras.losses import LogCosh, Huber
import tensorflow as tf

# %matplotlib inline
from rl.config import config
from rl.marketdata.yahoodownloader import YahooDownloader
from rl.preprocessing.preprocessors import FeatureEngineer
from rl.preprocessing.data import data_split
from rl.trade.backtest import backtest_stats, backtest_plot, get_daily_return, get_baseline
# Out:
# D:\InstalledSoftware\anaconda3\envs\py37-python-notebook\lib\site-packages\pyfolio\pos.py:26: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(

# %%
import os
if not os.path.exists("./" + config.DATA_SAVE_DIR):
    os.makedirs("./" + config.DATA_SAVE_DIR)
if not os.path.exists("./" + config.TRAINED_MODEL_DIR):
    os.makedirs("./" + config.TRAINED_MODEL_DIR)
if not os.path.exists("./" + config.TENSORBOARD_LOG_DIR):
    os.makedirs("./" + config.TENSORBOARD_LOG_DIR)
if not os.path.exists("./" + config.RESULTS_DIR):
    os.makedirs("./" + config.RESULTS_DIR)

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Dataset

# %% [markdown]
# Here is the dataset configuration:

# %%
# from config.py start_date is a string
start_date = config.START_DATE
# from config.py end_date is a string
end_date = config.END_DATE
# from config.py split_date is a string
split_date = config.SPLIT_DATE
# config target ticker
target_ticker = config.SP500_20_TICKER.copy()
target_ticker.extend(['SPY'])
# config tech_indicator_list
tech_indicator_list = config.TECHNICAL_INDICATORS_LIST
print("training period: {}-{}, testing period: {}-{}\n".format(start_date, split_date, split_date, end_date))
print("target ticker list:\n {}\n".format(target_ticker))
print("tech_indicator_list:\n {}\n".format(tech_indicator_list))
# Out:
# training period: 2000-01-01-2019-01-01, testing period: 2019-01-01-2021-01-01
#
# target ticker list:
#  ['AAPL', 'MSFT', 'AMZN', 'BRK-B', 'JPM', 'JNJ', 'UNH', 'HD', 'PG', 'NVDA', 'DIS', 'BAC', 'CMCSA', 'XOM', 'VZ', 'T', 'ADBE', 'PFE', 'CSCO', 'INTC', 'SPY']
#
# tech_indicator_list:
#  ['macd', 'boll_ub', 'boll_lb', 'rsi_10', 'rsi_20', 'cci_10', 'cci_20', 'dx_30', 'close_20_sma', 'close_60_sma', 'close_120_sma', 'close_20_ema', 'close_60_ema', 'close_120_ema']

# %%
df = YahooDownloader(start_date = start_date,
                     end_date = end_date,
                     ticker_list = target_ticker).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (110964, 8)

# %%
df.sort_values(['date','tic'],ignore_index=True).head()
# Out:
#          date       open       high        low      close       volume    tic  \
# 0  2000-01-03   0.936384   1.004464   0.907924   0.859423  535796800.0   AAPL
# 1  2000-01-03  16.812500  16.875000  16.062500  16.274673    7384400.0   ADBE
# 2  2000-01-03  81.500000  89.562500  79.046875  89.375000   16117600.0   AMZN
# 3  2000-01-03  25.125000  25.125000  24.000000  13.952057   13705800.0    BAC
# 4  2000-01-03  36.500000  36.580002  34.820000  35.299999     875000.0  BRK-B
#
#    day
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Add Technical Indicators

# %% [markdown]
# The feature engineering step would general technical indicators according to the original ticker's information.

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    tech_indicator_list = tech_indicator_list,
                    use_turbulence=True,
                    user_defined_feature = False)

processed = fe.preprocess_data(df)

processed.head()
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
list_ticker = processed["tic"].unique().tolist()
list_date = list(pd.date_range(processed['date'].min(),processed['date'].max()).astype(str))
combination = list(itertools.product(list_date,list_ticker))

processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(processed,on=["date","tic"],how="left")
processed_full = processed_full[processed_full['date'].isin(processed['date'])]
processed_full = processed_full.sort_values(['date','tic'])
processed_full = processed_full.fillna(0)

processed_full.sort_values(['date','tic'], ignore_index=True).head(10)

# %% [markdown]
# ### Example Data

# %%
SPY=processed_full[processed_full['tic']=='SPY']
SPY=SPY.reset_index(drop=True)

# %matplotlib inline

plt.figure(figsize=(16,6))
plt.title('Close Price History', fontsize=20)
plt.plot(SPY['close'])
plt.xlabel('date', fontsize=16)
plt.ylabel('Close Price USD ($)', fontsize=16)
plt.show()

# %% [markdown]
# ### Data Scaling

# %% [markdown]
# #### Logarithmic Conversion

# %% [markdown]
# During our previous training experience, we found many stock cannot fit well as the price goes high, but in historical pricing range, the directly trained model works acceptable. And then, we look back to the original dataset, there are some concerns training historical data to predict future.
# - the future price generally growth as company and total market growth, using the historical price related feature predict future somehow like using data predict out of training feature space points. As well as other patterns may only exist in near months dataset. Our solution is adopt rolling prediction method to predict future (in this project is 2019-01-01 to 2021-01-01) with near months data.
#
# Selected the close price from above example ticker, we could make some simple fit with linear and no-linear regression as following.
#
# Obviously, the sp index pricing follow the expenitial tendency, same as pricing direvative technical indicator.
#
# - the total market price increase more close to expnential than linear as following shows, if we could convert the no-linear data to a easier acceptable data by Deep Nerual Network, it would help to boost the model performance.

# %%
def linear_polyfit(ticker, ):
    coefficients=np.polyfit(np.array(range(len(ticker))), np.array(ticker['close']), 1)
    poly = np.poly1d(coefficients)
    poly_x = np.array(range(len(SPY)))
    poly_y = poly(poly_x)
    return poly_x, poly_y

def exp_polyfit(ticker, ):
    coefficients=np.polyfit(np.array(range(len(ticker))), np.log(np.array(ticker['close'])), 1)
    poly = np.poly1d(coefficients)
    poly_x = np.array(range(len(SPY)))
    poly_y = np.exp(poly(poly_x))
    return poly_x, poly_y

# %%
# %matplotlib inline

_, poly_y = linear_polyfit(SPY)
plt.figure()
plt.title('Close Price Linear Fit')
plt.plot(SPY['close'], label='close_price')
plt.plot(poly_y, label='linear_fit')
plt.xlabel('Date')
plt.ylabel('Close Price USD ($)')
plt.show()

_, poly_y = exp_polyfit(SPY)
plt.figure()
plt.title('Close Price Exp Fit')
plt.plot(SPY['close'], label='close_price')
plt.plot(poly_y, label='log_fit')
plt.xlabel('Date')
plt.yscale("log")
plt.ylabel('Close Price')
plt.show()

# %% [markdown]
# Here are several feature columns could be logarithmic convert.

# %%
# log convert price related values
log_feature_columns = ['close', 'open', 'high', 'low', 'boll_ub', 'boll_lb',
       'close_20_sma', 'close_60_sma', 'close_120_sma', 'close_20_ema',
       'close_60_ema', 'close_120_ema']

def log_convert(data, log_feature_columns):
    return data.apply(lambda x: np.log(x) if x.name in log_feature_columns else x)

processed_full=log_convert(processed_full, log_feature_columns)

# %% [markdown]
# #### Scaling Conversion

# %%
# Training feature_columns
feature_columns = ['close', 'open', 'high', 'low', 'volume', 'day', 'macd',
       'boll_ub', 'boll_lb', 'rsi_10', 'rsi_20', 'cci_10', 'cci_20', 'dx_30',
       'close_20_sma', 'close_60_sma', 'close_120_sma', 'close_20_ema',
       'close_60_ema', 'close_120_ema', 'turbulence']
# Out:
# Training data from 0 to 4779

# %%
def scale_df(df, feature_columns):
    tics = df.tic.unique()
    scalers = {}
    dataset = {}
    scaled_dataset = {}
    for tic in tics:
        dataset[tic] = df[df['tic']==tic].filter(feature_columns).values
        # Most of stock long term increase, so here may have some skew, reserve the range not full.
        scalers[tic] = MinMaxScaler(feature_range=(0.2,0.8))
        scaled_dataset[tic] = scalers[tic].fit_transform(dataset[tic])
    return scalers, dataset, scaled_dataset
scalers, dataset, scaled_dataset = scale_df(processed_full, feature_columns)

# %% [markdown]
# ### Time Window Conversion

# %% [markdown]
# Our target is convert original data to a continuous time series dataset. Here is the time series slices parameters define. The original data would be convert to continuous time slice dataset

# %%
# Time Series Data Hyperparameter Define:
shift = 1 # the target y offset from last x time series gap
input_width = 90 # the x input time windows width, per quarter
train_idx = 4779 # get date from 2000-01-01 to 2018-12-31

# %%
# Create the training data set 
# Create the scaled training data set
# Split the data into x_train and y_train data sets
def data_window_split(df, train_idx, input_width, shift):
    """
    Split dataset to time series windows
    df: data frame
    train_len: training dataset length
    input_width: training time series length
    shift: offset between x and y
    """
    x_train = []
    y_train = []
    x_test = []
    y_test = []
    for i in range(input_width - 1, len(df) - shift):
        if i <= train_idx:
            x_train.append(df[i - input_width + 1: i + 1, :])
            y_train.append(df[i + shift, 0])
        else:
            x_test.append(df[i - input_width + 1: i + 1, :])
            y_test.append(df[i + shift, 0])
    
    x_train, y_train, x_test, y_test = np.array(x_train), np.array(y_train), np.array(x_test), np.array(y_test)

    return x_train, y_train, x_test, y_test

def data_prepare(full_stock_data, train_idx, input_width, shift):
    """
    data_prepare: prepare dataset by ticker.
    """
    x_train_dict = {}
    y_train_dict = {}
    x_test_dict = {}
    y_test_dict = {}
    for k in full_stock_data.keys():
        data = full_stock_data[k]
        x_train_dict[k], y_train_dict[k], x_test_dict[k], y_test_dict[k] = data_window_split(data, train_idx, input_width, shift)
        
        print(k, '\t', x_train_dict[k].shape, y_train_dict[k].shape, x_test_dict[k].shape, y_test_dict[k].shape)
    return x_train_dict, y_train_dict, x_test_dict, y_test_dict

x_train_dict, y_train_dict, x_test_dict, y_test_dict = data_prepare(scaled_dataset, train_idx, input_width, shift)
# Out:
# AAPL (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# ADBE (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# AMZN (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# BAC (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# BRK-B (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# CMCSA (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# CSCO (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# DIS (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# HD (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# INTC (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# JNJ (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# JPM (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# MSFT (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# NVDA (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# PFE (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# PG (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# SPY (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# T (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# UNH (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# VZ (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# XOM (4691, 90, 21) (4691,) (503, 90, 21) (503,)

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Baseline Model

# %% [markdown]
# #### Hyperparameter Search

# %%
models = {}
histories = {}

# %%
units_option=[
    [128, 128, 32, 1],  
    [256, 128, 32, 1], [256, 256, 32, 1], 
    [512, 128, 32, 1], [512, 256, 32, 1], [512, 512, 64, 1],
]
units=[256,256,32,1]
dropout_option=[None,0.2,0.5]
dropout=None
loss_option=['mean_squared_error', 'mean_squared_logarithmic_error', 'mean_absolute_percentage_error', 'huber_loss', 'log_cosh']
loss='mean_squared_error'
batch_size_option=[8, 32, 128, 512]
batch_size=32
tic_option=['AAPL', 'MSFT', 'SPY', 'ALL']
tic='ALL'

# %%
def merge_tic(x_dict, y_dict):
    """
    Merge Tickers to one dataset
    """
    x = np.concatenate(tuple(x_dict.values()), axis=0)
    y = np.concatenate(tuple(y_dict.values()), axis=0)
    return x, y

# Build the LSTM model
def build_simple_lstm(units, dropout=None, optimizer='adam', loss='mean_squared_error'):
    model = Sequential()
    model.add(LSTM(units[0], return_sequences=True, input_shape=(input_width, len(feature_columns))))
    if dropout:
        model.add(Dropout(rate=dropout))
    model.add(LSTM(units[1], return_sequences=False))
    if dropout and dropout > 0.0:
        model.add(Dropout(rate=dropout))
    model.add(Dense(units[2]))
    if dropout:
        model.add(Dropout(rate=dropout))
    model.add(Dense(units[3]))
    model.compile(
        optimizer=optimizer, loss=loss
    )
    return model

def model_fit(
    x_train, 
    y_train, 
    model, 
    batch_size=1, 
    epochs=1, 
    validation_split=0.1,
    shuffle_split=True,
):
    if shuffle_split:
        x_train, y_train = shuffle(x_train, y_train)
    history = model.fit(
        x_train, 
        y_train, 
        batch_size = batch_size, 
        epochs=epochs, 
        validation_split=validation_split
    )
    return history

def model_fit_merge_tic(
    x_train_dict, 
    y_train_dict, 
    model, 
    batch_size=1, 
    epochs=1, 
    validation_split=0.1,
    shuffle_split=True,
):
    x_train, y_train = merge_tic(x_train_dict, y_train_dict)
    if shuffle_split:
        x_train, y_train = shuffle(x_train, y_train)
    history = model.fit(
        x_train, 
        y_train, 
        batch_size = batch_size, 
        epochs=epochs, 
        validation_split=validation_split
    )
    return history

def model_fit_per_tic(x_train_dict, y_train_dict, model, batch_size=1, epochs=1, validation_split=0.1, shuffle_split=True,):
    loss_r=[]
    val_loss_r=[]
    for i in range(epochs):
        print("======== epochs: {} ========".format(i))
        loss = []
        val_loss = []
        for k in x_train_dict:
            x_train, y_train = x_train_dict[k], y_train_dict[k]
            if shuffle_split:
                x_train, y_train = shuffle(x_train, y_train)
            history = model.fit(x_train, y_train, batch_size = batch_size, epochs=1, validation_split=validation_split)
            loss.append(history.history['loss'])
            val_loss.append(history.history['val_loss'])
        loss_r.append(np.mean(loss))
        val_loss_r.append(np.mean(val_loss))
    history.history['loss'] = loss_r
    history.history['val_loss'] = val_loss_r
    return history

# %%
def build_and_fit(idx, units, dropout, loss, batch_size, epochs, tic):
    model_name = 'lstm_{}'.format(idx)
    if batch_size > 100:
        epochs *= 2
    model_descr = {
        'units': units,
        'dropout': dropout,
        'loss': loss,
        'batch_size': batch_size,
        'epochs': epochs,
        'tic': tic
    }
    print("\n======== Model: {} ========\ndescription: {}\n".format(model_name, model_descr))
    model = build_simple_lstm(
        units=units, 
        dropout=dropout, 
        optimizer='adam', 
        loss=loss
    )
    if tic == 'ALL':
        history = model_fit_merge_tic(x_train_dict, y_train_dict, model, batch_size=batch_size, epochs=epochs)
    else:
        history = model_fit(x_train_dict[tic], y_train_dict[tic], model, batch_size=batch_size, epochs=epochs)
    ret = {
        'model_name': model_name,
        'model_descr': model_descr,
        'model': model,
        'history': history
    }
    return ret

def hyperparam_search(model_list, units_option, dropout_option, loss_option, tic_option, epochs=8):
    idx=0
    model_list.append(build_and_fit(idx, units, dropout, loss, batch_size, epochs, tic))
    idx+=1
    for d in dropout_option:
        model_list.append(build_and_fit(idx, units, d, loss, batch_size, epochs, tic))
        idx+=1
    for l in loss_option:
        model_list.append(build_and_fit(idx, units, dropout, l, batch_size, epochs, tic))
        idx+=1
    for b in batch_size_option:
        model_list.append(build_and_fit(idx, units, dropout, loss, b, epochs, tic))
        idx+=1
    for t in tic_option:
        model_list.append(build_and_fit(idx, units, dropout, loss, batch_size, epochs, t))
        idx+=1
    for u in units_option:
        model_list.append(build_and_fit(idx, u, dropout, loss, batch_size, epochs, tic))
        idx+=1
    return model_list

# %%
model_list=[]
hyperparam_search(model_list, units_option, dropout_option, loss_option, tic_option, epochs=25)
# Out:
# ======== Model: lstm_0 ========
# description: {'units': [256, 256, 32, 1], 'dropout': None, 'loss': 'mean_squared_error', 'batch_size': 32, 'epochs': 25, 'tic': 'ALL'}
#
# Epoch 1/25
# 2771/2771 [==============================] -
25
# 2771/2771 [==============================] - 63s 23ms/step - loss: 3.0678e-05 - val_loss: 2.3759e-05
# Epoch 22/25
# 2771/2771 [==============================] - 61s 22ms/step - loss: 3.0357e-05 - val_loss: 3.0308e-05
# Epoch 23/25
# 2771/2771 [==============================] - 64s 23ms/step - loss: 2.9088e-05 - val_loss: 3.5012e-05
# Epoch 24/25
# 2771/2771 [==============================] - 60s 22ms/step - loss: 2.9041e-05 - val_loss: 2.9278e-05
# Epoch 25/25
# 2771/2771 [==============================] - 64s 23ms/step - loss: 2.9435e-05 - val_loss: 2.6116e-05
#
# ======== Model: lstm_2 ========
# description: {'units': [256, 256, 32, 1], 'dropout': 0.2, 'loss': 'mean_squared_error', 'batch_size': 32, 'epochs': 25, 'tic': 'ALL'}
#
# Epoch 1/25
# 2771/2771 [==============================] - 64s 22ms/step - loss: 0.0102 - val_loss: 1.1870e-04
# Epoch 2/25
# 2771/2771 [==============================] - 62s 23ms/step - loss: 7.1441e-04 - val_loss: 7.4410e-05
# Epoch 3/25
# 2771/2771 [==============================] - 60s 22ms/step - loss: 3.7442e-04 - val_loss: 1.1460e-04
# Epoch 4/25
# 2771/2771 [==============================] - 62s 22ms/step - loss: 3.3375e-04 - val_loss: 1.4534e-04
# Epoch 5/25
# 2771/2771 [==============================] - 62s 22ms/step - loss: 3.0374e-04 - val_loss: 1.5237e-04
# Epoch 6/25
# 2771/2771 [==============================] - 60s 22ms/step - loss: 2.9067e-04 - val_loss: 4.3763e-05
# Epoch 7/25
# 2771/2771 [==============================] - 62s 22ms/step - loss: 2.8159e-04 - val_loss: 1.1438e-04
# Epoch 8/25
# 2771/2771 [==============================] - 61s 22ms/step - loss: 2.6964e-04 - val_loss: 2.1375e-04
# Epoch 9/25
# 2771/2771 [==============================] - 62s 22ms/step - loss: 2.6827e-04 - val_loss: 7.0661e-05
# Epoch 10/25
# 2771/2771 [==============================] - 61s 22ms/step - loss: 2.5909e-04 - val_loss: 5.3879e-05
# Epoch 11/25
# 2771/2771 [==============================] - 62s 22ms/step - loss: 2.5537e-04 - val_loss: 6.0127e-05
# Epoch 12/25
# 2771/2771 [==============================] - 60s 22ms/step - loss: 2.5125e-04 - val_loss: 4.5393e-05
# Epoch 13/25
# 2771/2771 [==============================] - 61s 22ms/step - loss: 2.6000e-04 - val_loss: 8.5508e-05
# Epoch 14/25
# 2771/2771 [==============================] - 60s 22ms/step - loss: 2.5355e-04 - val_loss: 3.5879e-05
# Epoch 15/25
# 2771/2771 [==============================] - 61s 22ms/step - loss: 2.4017e-04 - val_loss: 4.4365e-05
# Epoch 16/25
# 2771/2771 [==============================] - 60s 22ms/step - loss: 2.4489e-04 - val_loss: 6.7333e-05
# Epoch 17/25
# 2771/2771 [==============================] - 60s 22ms/step - loss: 2.3751e-04 - val_loss: 3.1961e-05
# Epoch 18/25
# 2771/2771 [==============================] - 61s 22ms/step - loss: 2.3377e-04 - val_loss: 6.7186e-05
# Epoch 19/25
# 2771/2771 [==============================] - 60s 22ms/step - loss: 2.4225e-04 - val_loss: 5.2481e-05
# Epoch 20/25
# 2771/2771 [==============================] - 61s 22ms/step - loss: 2.3569e-04 - val_loss: 3.2956e-05
# Epoch 21/25
# 2771/2771 [==============================] - 62s 22ms/step - loss: 2.4115e-04 - val_loss: 5.8687e-05
# Epoch 22/25
# 2771/2771 [==============================] - 61s 22ms/step - loss: 2.2865e-04 - val_loss: 2.8370e-05
# Epoch 23/25
# 2771/2771 [==============================] - 60s 22ms/step - loss: 2.3886e-04 - val_loss: 7.1691e-05
# Epoch 24/25
# 2771/2771 [==============================] - 58s 21ms/step - loss: 2.3723e-04 - val_loss: 1.2599e-04
# Epoch 25/25
# 2771/2771 [==============================] - 61s 22ms/step - loss: 2.3352e-04 - val_loss: 4.8620e-05
#
# ======== Model: lstm_3 ========
# description: {'units': [256, 256, 32, 1], 'dropout': 0.5, 'loss': 'mean_squared_error', 'batch_size': 32, 'epochs': 25, 'tic': 'ALL'}
#
# Epoch 1/25
# 2771/2771 [==============================] - 64s 22ms/step - loss: 0.0112 - val_loss: 1.8523e-04
# Epoch 2/25
# 2771/2771 [==============================] - 61s 22ms/step - loss: 0.0012 - val_loss: 4.9237e-04
# Epoch 3/25
# 2771/2771 [==============================] - 62s 22ms/step - loss: 0.0011 - val_loss: 1.0603e-04
# Epoch 4/25
# 2771/2771 [==============================] - 60s 22ms/step - loss: 9.6469e-04 - val_loss: 1.0613e-04
# Epoch 5/25
# 2771/2771 [==============================] - 63s 23ms/step - loss: 9.2233e-04 - val_loss: 1.6212e-04
# Epoch 6/25
# 2771/2771 [==============================] - 61s 22ms/step - loss: 9.1076e-04 - val_loss: 1.5021e-04
# Epoch 7/25
# 2771/2771 [==============================] - 60s 22ms/step - loss: 9.0403e-04 - val_loss: 9.9398e-05
# Epoch 8/25
# 2771/2771 [==============================] - 62s 22ms/step - loss: 8.8950e-04 - val_loss: 9.6144e-05
# Epoch 9/25
# 2771/2771 [==============================] - 59s 21ms/step - loss: 8.7033e-04 - val_loss: 7.8820e-05
# Epoch 10/25
# 2771/2771 [==============================] - 60s 22ms/step - loss: 8.5174e-04 - val_loss: 9.3217e-05
# Epoch 11/25
# 2771/2771 [==============================] - 60s 22ms/step - loss: 8.4696e-04 - val_loss: 1.6195e-04
# Epoch 12/25
# 2771/2771 [==============================] - 59s 21ms/step - loss: 8.5385e-04 - val_loss: 8.2806e-05
# Epoch 13/25
# 2771/2771 [==============================] - 62s 22ms/step - loss: 8.2254e-04 - val_loss: 9.4269e-05
# Epoch 14/25
# 2771/2771 [==============================] - 60s 22ms/step - loss: 8.2829e-04 - val_loss: 6.4117e-05
# Epoch 15/25
# 2771/2771 [==============================] - 59s 21ms/step - loss: 8.1349e-04 - val_loss: 5.8401e-05
# Epoch 16/25
# 2771/2771 [==============================] - 61s 22ms/step - loss: 8.2277e-04 - val_loss: 8.0277e-05
# Epoch 17/25
# 2771/2771 [==============================] - 60s 22ms/step - loss: 8.0143e-04 - val_loss: 2.0121e-04
# Epoch 18/25
# 2771/2771 [==============================] - 63s 23ms/step - loss: 7.8652e-04 - val_loss: 1.7253e-04
# Epoch 19/25
# 2771/2771 [==============================] - 61s 22ms/step - loss: 8.0054e-04 - val_loss: 3.9390e-05
# Epoch 20/25
# 2771/2771 [==============================] - 60s 22ms/step - loss: 7.8919e-04 - val_loss: 2.1515e-04
# Epoch 21/25
# 2771/2771 [==============================] - 64s 23ms/step - loss: 7.8098e-04 - val_loss: 8.4199e-05
# Epoch 22/25
# 2771/2771 [==============================] - 63s 23ms/step - loss: 7.8346e-04 - val_loss: 1.4022e-04
# Epoch 23/25
# 2771/2771 [==============================] - 61s 22ms/step - loss: 7.8998e-04 - val_loss: 6.3437e-05
# Epoch 24/25
# 2771/2771 [==============================] - 60s 22ms/step - loss: 7.8651e-04 - val_loss: 2.7534e-04
# Epoch 25/25
# 2771/2771 [==============================] - 63s 23ms/step - loss: 7.8259e-04 - val_loss: 1.1388e-04
#
# ======== Model: lstm_4 ========
# description: {'units': [256, 256, 32, 1], 'dropout': None, 'loss': 'mean_squared_error', 'batch_size': 32, 'epochs': 25, 'tic': 'ALL'}
#
# Epoch 1/25
# 2771/2771 [==============================] - 66s 23ms/step - loss: 0.0057 - val_loss: 1.0987e-04
# Epoch 2/25
# 2771/2771 [==============================] - 62s 22ms/step - loss: 9.3064e-05 - val_loss: 6.9382e-05
# Epoch 3/25
# 2771/2771 [==============================] - 62s 22ms/step - loss: 7.1717e-05 - val_loss: 3.3317e-05
# Epoch 4/25
# 2771/2771 [==============================] - 62s 23ms/step - loss: 6.1517e-05 - val_loss: 1.9219e-04
# Epoch 5/25
# 2771/2771 [==============================] - 63s 23ms/step - loss: 5.1649e-05 - val_loss: 5.6588e-05
# Epoch 6/25
# 2771/2771 [==============================] - 62s 22ms/step - loss: 4.4522e-05 - val_loss: 1.0120e-04
# Epoch 7/25
# 2771/2771 [==============================] - 61s 22ms/step - loss: 3.8834e-05 - val_loss: 2.7923e-05
# Epoch 8/25
# 2771/2771 [==============================] - 61s 22ms/step - loss: 3.8617e-05 - val_loss: 2.6588e-05
# Epoch 9/25
# 2771/2771 [==============================] - 63s 23ms/step - loss: 3.6110e-05 - val_loss: 2.6496e-05
# Epoch 10/25
# 2771/2771 [==============================] - 62s 22ms/step - loss: 3.7015e-05 - val_loss: 2.9184e-05
# Epoch 11/25
# 2771/2771 [==============================] - 63s 23ms/step - loss: 3.4723e-05 - val_loss: 4.3983e-05
# Epoch 12/25
# 2771/2771 [==============================] - 61s 22ms/step - loss: 3.3706e-05 - val_loss: 2.4522e-05
# Epoch 13/25
# 2771/2771 [==============================] - 62s 22ms/step - loss: 3.2802e-05 - val_loss: 2.5987e-05
# Epoch 14/25
# 2771/2771 [==============================] - 62s 22ms/step - loss: 3.2913e-05 - val_loss: 2.7759e-05
# Epoch 15/25
# 2771/2771 [==============================] - 62s 22ms/step - loss: 3.2863e-05 - val_loss: 2.8157e-05
# Epoch 16/25
# 2771/2771 [==============================] - 62s 22ms/step - loss: 3.1327e-05 - val_loss: 3.6301e-05
# Epoch 17/25
# 2771/2771 [==============================] - 61s 22ms/step - loss: 3.1997e-05 - val_loss: 2.4049e-05
# Epoch 18/25
# 2771/2771 [==============================] - 61s 22ms/step - loss: 2.9950e-05 - val_loss: 6.3488e-05
# Epoch 19/25
# 2771/2771 [==============================] - 62s 22ms/step - loss: 3.3392e-05 - val_loss: 3.7819e-05
# Epoch 20/25
# 2771/2771 [==============================] - 62s 22ms/step - loss: 2.9500e-05 - val_loss: 3.9134e-05
# Epoch 21/25
# 2771/2771 [==============================] - 61s 22ms/step - loss: 2.9853e-05 - val_loss: 5.1809e-05
# Epoch 22/25
# 2771/2771 [==============================] - 63s 23ms/step - loss: 3.0108e-05 - val_loss: 2.8074e-05
# Epoch 23/25
# 2771/2771 [==============================] - 62s 22ms/step - loss: 2.9171e-05 - val_loss: 4.0367e-05
# Epoch 24/25
# 2771/2771 [==============================] - 62s 22ms/step - loss: 3.0208e-05 - val_loss: 2.5293e-05
# Epoch 25/25
# 2771/2771 [==============================] - 61s 22ms/step - loss: 2.9495e-05 - val_loss: 3.3296e-05
#
# ======== Model: lstm_5 ========
# description: {'units': [256, 256, 32, 1], 'dropout': None, 'loss': 'mean_squared_logarithmic_error', 'batch_size': 32, 'epochs': 25, 'tic': 'ALL'}
#
# Epoch 1/25
# 2771/2771 [==============================] - 68s 23ms/step - loss: 0.0015 - val_loss: 2.1928e-05
# Epoch 2/25
# 2771/2771 [==============================] - 64s 23ms/step - loss: 3.9010e-05 - val_loss: 2.8295e-05
# Epoch 3/25
# 2771/2771 [==============================] - 64s 23ms/step - loss: 3.1788e-05 - val_loss: 1.5714e-05
# Epoch 4/25
# 2771/2771 [==============================] - 63s 23ms/step - loss: 2.4923e-05 - val_loss: 1.4921e-05
# Epoch 5/25
# 2771/2771 [==============================] - 65s 23ms/step - loss: 2.3087e-05 - val_loss: 3.0514e-05
# Epoch 6/25
# 2771/2771 [==============================] - 62s 22ms/step - loss: 2.0614e-05 - val_loss: 1.2716e-05
# Epoch 7/25
# 2771/2771 [==============================] - 63s 23ms/step - loss: 1.8703e-05 - val_loss: 1.3039e-05
# Epoch 8/25
# 2771/2771 [==============================] - 62s 23ms/step - loss: 1.8119e-05 - val_loss: 1.6265e-05
# Epoch 9/25
# 2771/2771 [==============================] - 62s 22ms/step - loss: 1.7456e-05 - val_loss: 2.3843e-05
# Epoch 10/25
# 2771/2771 [==============================] - 62s 22ms/step - loss: 1.6530e-05 - val_loss: 1.8094e-05
# Epoch 11/25
# 2771/2771 [==============================] - 64s 23ms/step - loss: 1.6436e-05 - val_loss: 1.2939e-05
# Epoch 12/25
# 2771/2771 [==============================] - 63s 23ms/step - loss: 1.6740e-05 - val_loss: 2.1623e-05
# Epoch 13/25
# 2771/2771 [==============================] - 63s 23ms/step - loss: 1.6457e-05 - val_loss: 1.3649e-05
# Epoch 14/25
# 2771/2771 [==============================] - 64s 23ms/step - loss: 1.5468e-05 - val_loss: 1.2992e-05
# Epoch 15/25
# 2771/2771 [==============================] - 65s 23ms/step - loss: 1.5349e-05 - val_loss: 1.6203e-05
# Epoch 16/25
# 2771/2771 [==============================] - 61s 22ms/step - loss: 1.5921e-05 - val_loss: 1.3738e-05
# Epoch 17/25
# 2771/2771 [==============================] - 64s 23ms/step - loss: 1.5002e-05 - val_loss: 1.2091e-05
# Epoch 18/25
# 2771/2771 [==============================] - 65s 23ms/step - loss: 1.5971e-05 - val_loss: 1.8331e-05
# Epoch 19/25
# 2771/2771 [==============================] - 64s 23ms/step - loss: 1.5181e-05 - val_loss: 1.4435e-05
# Epoch 20/25
# 2771/2771 [==============================] - 65s 24ms/step - loss: 1.5510e-05 - val_loss: 1.3149e-05
# Epoch 21/25
# 2771/2771 [==============================] - 60s 22ms/step - loss: 1.4639e-05 - val_loss: 1.5258e-05
# Epoch 22/25
# 2771/2771 [==============================] - 64s 23ms/step - loss: 1.4747e-05 - val_loss: 1.2039e-05
# Epoch 23/25
# 2771/2771 [==============================] - 61s 22ms/step - loss: 1.4209e-05 - val_loss: 1.2926e-05
# Epoch 24/25
# 2771/2771 [==============================] - 64s 23ms/step - loss: 1.4393e-05 - val_loss: 1.4493e-05
# Epoch 25/25
# 2771/2771 [==============================] - 61s 22ms/step - loss: 1.4288e-05 - val_loss: 1.5205e-05
#
# ======== Model: lstm_6 ========
# description: {'units': [256, 256, 32, 1], 'dropout': None, 'loss': 'mean_absolute_percentage_error', 'batch_size': 32, 'epochs': 25, 'tic': 'ALL'}
#
# Epoch 1/25
# 2771/2771 [==============================] - 67s 24ms/step - loss: 4.4735 - val_loss: 1.6047
# Epoch 2/25
# 2771/2771 [==============================] - 64s 23ms/step - loss: 1.7183 - val_loss: 1.0079
# Epoch 3/25
# 2771/2771 [==============================] - 64s 23ms/step - loss: 1.4106 - val_loss: 0.9401
# Epoch 4/25
# 2771/2771 [==============================] - 62s 22ms/step - loss: 1.3314 - val_loss: 1.2565
# Epoch 5/25
# 2771/2771 [==============================] - 64s 23ms/step - loss: 1.1744 - val_loss: 1.4184
# Epoch 6/25
# 2771/2771 [==============================] - 63s 23ms/step - loss: 1.1607 - val_loss: 1.2243
# Epoch 7/25
# 2771/2771 [==============================] - 64s 23ms/step - loss: 1.1080 - val_loss: 0.8497
# Epoch 8/25
# 2771/2771 [==============================] - 61s 22ms/step - loss: 1.1133 - val_loss: 1.2223
# Epoch 9/25
# 2771/2771 [==============================] - 65s 23ms/step - loss: 1.1054 - val_loss: 0.8036
# Epoch 10/25
# 2771/2771 [==============================] - 62s 22ms/step - loss: 1.0199 - val_loss: 0.8123
# Epoch 11/25
# 2771/2771 [==============================] - 64s 23ms/step - loss: 1.0468 - val_loss: 1.5581
# Epoch 12/25
# 2771/2771 [==============================] - 63s 23ms/step - loss: 1.0037 - val_loss: 0.7733
# Epoch 13/25
# 2771/2771 [==============================] - 65s 24ms/step - loss: 0.9633 - val_loss: 1.1343
# Epoch 14/25
# 2771/2771 [==============================] - 61s 22ms/step - loss: 0.9617 - val_loss: 0.8238
# Epoch 15/25
# 2771/2771 [==============================] - 64s 23ms/step - loss: 0.9639 - val_loss: 0.9994
# Epoch 16/25
# 2771/2771 [==============================] - 62s 23ms/step - loss: 0.9374 - val_loss: 0.7856
# Epoch 17/25
# 2771/2771 [==============================] - 63s 23ms/step - loss: 0.9447 - val_loss: 0.9212
# Epoch 18/25
# 2771/2771 [==============================] - 61s 22ms/step - loss: 0.9795 - val_loss: 0.8290
# Epoch 19/25
# 2771/2771 [==============================] - 64s 23ms/step - loss: 0.9193 - val_loss: 0.8063
# Epoch 20/25
# 2771/2771 [==============================] - 62s 22ms/step - loss: 0.9370 - val_loss: 0.8684
# Epoch 21/25
# 2771/2771 [==============================] - 64s 23ms/step - loss: 0.9064 - val_loss: 1.0805
# Epoch 22/25
# 2771/2771 [==============================] - 63s 23ms/step - loss: 0.9260 - val_loss: 1.2003
# Epoch 23/25
# 2771/2771 [==============================] - 62s 22ms/step - loss: 0.9204 - val_loss: 0.7381
# Epoch 24/25
# 2771/2771 [==============================] - 63s 23ms/step - loss: 0.9091 - val_loss: 0.7599
# Epoch 25/25
# 2771/2771 [==============================] - 62s 23ms/step - loss: 0.8843 - val_loss: 0.7920
#
# ======== Model: lstm_7 ========
# description: {'units': [256, 256, 32, 1], 'dropout': None, 'loss': 'huber_loss', 'batch_size': 32, 'epochs': 25, 'tic': 'ALL'}
#
# Epoch 1/25
# 2771/2771 [==============================] - 68s 23ms/step - loss: 0.0022 - val_loss: 6.5434e-05
# Epoch 2/25
# 2771/2771 [==============================] - 63s 23ms/step - loss: 4.2631e-05 - val_loss: 1.7948e-05
# Epoch 3/25
# 2771/2771 [==============================] - 63s 23ms/step - loss: 4.0633e-05 - val_loss: 2.5443e-05
# Epoch 4/25
# 2771/2771 [==============================] - 61s 22ms/step - loss: 2.9902e-05 - val_loss: 3.9596e-05
# Epoch 5/25
# 2771/2771 [==============================] - 63s 23ms/step - loss: 2.4589e-05 - val_loss: 1.3898e-05
# Epoch 6/25
# 2771/2771 [==============================] - 62s 23ms/step - loss: 2.4101e-05 - val_loss: 1.3367e-05
# Epoch 7/25
# 2771/2771 [==============================] - 64s 23ms/step - loss: 2.0489e-05 - val_loss: 1.5718e-05
# Epoch 8/25
# 2771/2771 [==============================] - 62s 22ms/step - loss: 1.9104e-05 - val_loss: 2.2313e-05
# Epoch 9/25
# 2771/2771 [==============================] - 64s 23ms/step - loss: 1.8410e-05 - val_loss: 1.1787e-05
# Epoch 10/25
# 2771/2771 [==============================] - 61s 22ms/step - loss: 1.8102e-05 - val_loss: 1.6713e-05
# Epoch 11/25
# 2771/2771 [==============================] - 66s 24ms/step - loss: 1.7297e-05 - val_loss: 1.1617e-05
# Epoch 12/25
# 2771/2771 [==============================] - 63s 23ms/step - loss: 1.7870e-05 - val_loss: 1.7164e-05
# Epoch 13/25
# 2771/2771 [==============================] - 65s 23ms/step - loss: 1.6751e-05 - val_loss: 1.6507e-05
# Epoch 14/25
# 2771/2771 [==============================] - 61s 22ms/step - loss: 1.7215e-05 - val_loss: 1.3388e-05
# Epoch 15/25
# 2771/2771 [==============================] - 65s 23ms/step - loss: 1.6677e-05 - val_loss: 1.2778e-05
# Epoch 16/25
# 2771/2771 [==============================] - 62s 22ms/step - loss: 1
25
# 2771/2771 [==============================] - 67s 24ms/step - loss: 4.9576e-05 - val_loss: 1.4213e-04
# Epoch 6/25
# 2771/2771 [==============================] - 66s 24ms/step - loss: 4.5487e-05 - val_loss: 2.5844e-05
# Epoch 7/25
# 2771/2771 [==============================] - 68s 25ms/step - loss: 4.2128e-05 - val_loss: 7.1691e-05
# Epoch 8/25
# 2771/2771 [==============================] - 66s 24ms/step - loss: 3.9931e-05 - val_loss: 4.8213e-05
# Epoch 9/25
# 2771/2771 [==============================] - 69s 25ms/step - loss: 3.6574e-05 - val_loss: 2.4817e-05
# Epoch 10/25
# 2771/2771 [==============================] - 65s 23ms/step - loss: 3.5863e-05 - val_loss: 2.9064e-05
# Epoch 11/25
# 2771/2771 [==============================] - 67s 24ms/step - loss: 3.5223e-05 - val_loss: 2.9244e-05
# Epoch 12/25
# 2771/2771 [==============================] - 67s 24ms/step - loss: 3.4693e-05 - val_loss: 3.8476e-05
# Epoch 13/25
# 2771/2771 [==============================] - 67s 24ms/step - loss: 3.5314e-05 - val_loss: 2.9947e-05
# Epoch 14/25
# 2771/2771 [==============================] - 68s 24ms/step - loss: 3.0980e-05 - val_loss: 6.6231e-05
# Epoch 15/25
# 2771/2771 [==============================] - 67s 24ms/step - loss: 3.2260e-05 - val_loss: 2.8268e-05
# Epoch 16/25
# 2771/2771 [==============================] - 66s 24ms/step - loss: 3.0953e-05 - val_loss: 2.4495e-05
# Epoch 17/25
# 2771/2771 [==============================] - 67s 24ms/step - loss: 3.0092e-05 - val_loss: 2.8428e-05
# Epoch 18/25
# 2771/2771 [==============================] - 66s 24ms/step - loss: 3.1715e-05 - val_loss: 2.7828e-05
# Epoch 19/25
# 2771/2771 [==============================] - 67s 24ms/step - loss: 3.1285e-05 - val_loss: 2.5269e-05
# Epoch 20/25
# 2771/2771 [==============================] - 67s 24ms/step - loss: 2.9845e-05 - val_loss: 3.6992e-05
# Epoch 21/25
# 2771/2771 [==============================] - 67s 24ms/step - loss: 3.0953e-05 - val_loss: 2.3081e-05
# Epoch 22/25
# 2771/2771 [==============================] - 66s 24ms/step - loss: 3.0305e-05 - val_loss: 3.0371e-05
# Epoch 23/25
# 2771/2771 [==============================] - 67s 24ms/step - loss: 2.8718e-05 - val_loss: 5.2476e-05
# Epoch 24/25
# 2771/2771 [==============================] - 67s 24ms/step - loss: 2.9177e-05 - val_loss: 5.2176e-05
# Epoch 25/25
# 2771/2771 [==============================] - 67s 24ms/step - loss: 3.0968e-05 - val_loss: 2.3564e-05
#
# ======== Model: lstm_22 ========
# description: {'units': [512, 512, 64, 1], 'dropout': None, 'loss': 'mean_squared_error', 'batch_size': 32, 'epochs': 25, 'tic': 'ALL'}
#
# Epoch 1/25
# 2771/2771 [==============================] - 75s 26ms/step - loss: 0.0210 - val_loss: 7.7010e-05
# Epoch 2/25
# 2771/2771 [==============================] - 71s 26ms/step - loss: 8.3158e-05 - val_loss: 2.4010e-04
# Epoch 3/25
# 2771/2771 [==============================] - 72s 26ms/step - loss: 8.5629e-05 - val_loss: 3.8262e-05
# Epoch 4/25
# 2771/2771 [==============================] - 72s 26ms/step - loss: 7.6852e-05 - val_loss: 3.8900e-05
# Epoch 5/25
# 2771/2771 [==============================] - 71s 26ms/step - loss: 0.0663 - val_loss: 5.1960e-04
# Epoch 6/25
# 2771/2771 [==============================] - 72s 26ms/step - loss: 6.3104e-04 - val_loss: 5.5147e-04
# Epoch 7/25
# 2771/2771 [==============================] - 71s 26ms/step - loss: 3.9649e-04 - val_loss: 1.3313e-04
# Epoch 8/25
# 2771/2771 [==============================] - 72s 26ms/step - loss: 2.9602e-04 - val_loss: 1.0712e-04
# Epoch 9/25
# 2771/2771 [==============================] - 71s 26ms/step - loss: 2.1983e-04 - val_loss: 8.4960e-05
# Epoch 10/25
# 2771/2771 [==============================] - 71s 26ms/step - loss: 1.6216e-04 - val_loss: 1.2562e-04
# Epoch 11/25
# 2771/2771 [==============================] - 71s 26ms/step - loss: 1.2235e-04 - val_loss: 6.0157e-05
# Epoch 12/25
# 2771/2771 [==============================] - 73s 26ms/step - loss: 9.4654e-05 - val_loss: 4.8259e-05
# Epoch 13/25
# 2771/2771 [==============================] - 71s 26ms/step - loss: 8.3548e-05 - val_loss: 4.3372e-05
# Epoch 14/25
# 2771/2771 [==============================] - 72s 26ms/step - loss: 7.7612e-05 - val_loss: 4.0416e-05
# Epoch 15/25
# 2771/2771 [==============================] - 71s 26ms/step - loss: 6.7703e-05 - val_loss: 1.0270e-04
# Epoch 16/25
# 2771/2771 [==============================] - 71s 26ms/step - loss: 6.4465e-05 - val_loss: 7.6217e-05
# Epoch 17/25
# 2771/2771 [==============================] - 72s 26ms/step - loss: 5.7163e-05 - val_loss: 5.5806e-05
# Epoch 18/25
# 2771/2771 [==============================] - 71s 26ms/step - loss: 5.4289e-05 - val_loss: 3.7403e-05
# Epoch 19/25
# 2771/2771 [==============================] - 71s 26ms/step - loss: 5.1515e-05 - val_loss: 3.2745e-05
# Epoch 20/25
# 2771/2771 [==============================] - 71s 26ms/step - loss: 4.7940e-05 - val_loss: 6.3070e-05
# Epoch 21/25
# 2771/2771 [==============================] - 70s 25ms/step - loss: 4.6877e-05 - val_loss: 4.2125e-05
# Epoch 22/25
# 2771/2771 [==============================] - 71s 26ms/step - loss: 4.4643e-05 - val_loss: 3.1166e-05
# Epoch 23/25
# 2771/2771 [==============================] - 70s 25ms/step - loss: 4.4464e-05 - val_loss: 4.1303e-05
# Epoch 24/25
# 2771/2771 [==============================] - 71s 26ms/step - loss: 4.2877e-05 - val_loss: 5.3424e-05
# Epoch 25/25
# 2771/2771 [==============================] - 71s 26ms/step - loss: 4.1539e-05 - val_loss: 2.9026e-05
# [{'model_name': 'lstm_0',
#   'model_descr': {'units': [256, 256, 32, 1],
#    'dropout': None,
#    'loss': 'mean_squared_error',
#    'batch_size': 32,
#    'epochs': 25,
#    'tic': 'ALL'},
#   'model': <tensorflow.python.keras.engine.sequential.Sequential at 0x20c406ad3a0>,
#   'history': <tensorflow.python.keras.callbacks.History at 0x20c412cc3d0>},
#  {'model_name': 'lstm_1',
#   'model_descr': {'units': [256, 256, 32, 1],
#    'dropout': None,
#    'loss': 'mean_squared_error',
#    'batch_size': 32,
#    'epochs': 25,
#    'tic': 'ALL'},
#   'model': <tensorflow.python.keras.engine.sequential.Sequential at 0x20c412c3dc0>,
#   'history': <tensorflow.python.keras.callbacks.History at 0x20c8cf278e0>},
#  {'model_name': 'lstm_2',
#   'model_descr': {'units': [256, 256, 32, 1],
#    'dropout': 0.2,
#    'loss': 'mean_squared_error',
#    'batch_size': 32,
#    'epochs': 25,
#    'tic': 'ALL'},
#   'model': <tensorflow.python.keras.engine.sequential.Sequential at 0x20c2d19dc10>,
#   'history': <tensorflow.python.keras.callbacks.History at 0x20f173b4b20>},
#  {'model_name': 'lstm_3',
#   'model_descr': {'units': [256, 256, 32, 1],
#    'dropout': 0.5,
#    'loss': 'mean_squared_error',
#    'batch_size': 32,
#    'epochs': 25,
#    'tic': 'ALL'},
#   'model': <tensorflow.python.keras.engine.sequential.Sequential at 0x20f173d5430>,
#   'history': <tensorflow.python.keras.callbacks.History at 0x20f721423a0>},
#  {'model_name': 'lstm_4',
#   'model_descr': {'units': [256, 256, 32, 1],
#    'dropout': None,
#    'loss': 'mean_squared_error',
#    'batch_size': 32,
#    'epochs': 25,
#    'tic': 'ALL'},
#   'model': <tensorflow.python.keras.engine.sequential.Sequential at 0x20f7215b280>,
#   'history': <tensorflow.python.keras.callbacks.History at 0x20fa5ee5b80>},
#  {'model_name': 'lstm_5',
#   'model_descr': {'units': [256, 256, 32, 1],
#    'dropout': None,
#    'loss': 'mean_squared_logarithmic_error',
#    'batch_size': 32,
#    'epochs': 25,
#    'tic': 'ALL'},
#   'model': <tensorflow.python.keras.engine.sequential.Sequential at 0x20fb16cf5b0>,
#   'history': <tensorflow.python.keras.callbacks.History at 0x20fd9c02a30>},
#  {'model_name': 'lstm_6',
#   'model_descr': {'units': [256, 256, 32, 1],
#    'dropout': None,
#    'loss': 'mean_absolute_percentage_error',
#    'batch_size': 32,
#    'epochs': 25,
#    'tic': 'ALL'},
#   'model': <tensorflow.python.keras.engine.sequential.Sequential at 0x20fd9c1bb20>,
#   'history': <tensorflow.python.keras.callbacks.History at 0x20fe7a2e100>},
#  {'model_name': 'lstm_7',
#   'model_descr': {'units': [256, 256, 32, 1],
#    'dropout': None,
#    'loss': 'huber_loss',
#    'batch_size': 32,
#    'epochs': 25,
#    'tic': 'ALL'},
#   'model': <tensorflow.python.keras.engine.sequential.Sequential at 0x2100f986400>,
#   'history': <tensorflow.python.keras.callbacks.History at 0x21042705070>},
#  {'model_name': 'lstm_8',
#   'model_descr': {'units': [256, 256, 32, 1],
#    'dropout': None,
#    'loss': 'log_cosh',
#    'batch_size': 32,
#    'epochs': 25,
#    'tic': 'ALL'},
#   'model': <tensorflow.python.keras.engine.sequential.Sequential at 0x2104271f430>,
#   'history': <tensorflow.python.keras.callbacks.History at 0x210764c2b80>},
#  {'model_name': 'lstm_9',
#   'model_descr': {'units': [256, 256, 32, 1],
#    'dropout': None,
#    'loss': 'mean_squared_error',
#    'batch_size': 8,
#    'epochs': 25,
#    'tic': 'ALL'},
#   'model': <tensorflow.python.keras.engine.sequential.Sequential at 0x20fb1c15040>,
#   'history': <tensorflow.python.keras.callbacks.History at 0x210aa21be50>},
#  {'model_name': 'lstm_10',
#   'model_descr': {'units': [256, 256, 32, 1],
#    'dropout': None,
#    'loss': 'mean_squared_error',
#    'batch_size': 32,
#    'epochs': 25,
#    'tic': 'ALL'},
#   'model': <tensorflow.python.keras.engine.sequential.Sequential at 0x21081e49280>,
#   'history': <tensorflow.python.keras.callbacks.History at 0x210dcf76cd0>},
#  {'model_name': 'lstm_11',
#   'model_descr': {'units': [256, 256, 32, 1],
#    'dropout': None,
#    'loss': 'mean_squared_error',
#    'batch_size': 128,
#    'epochs': 50,
#    'tic': 'ALL'},
#   'model': <tensorflow.python.keras.engine.sequential.Sequential at 0x210dcf8fe20>,
#   'history': <tensorflow.python.keras.callbacks.History at 0x21110ca7b20>},
#  {'model_name': 'lstm_12',
#   'model_descr': {'units': [256, 256, 32, 1],
#    'dropout': None,
#    'loss': 'mean_squared_error',
#    'batch_size': 512,
#    'epochs': 50,
#    'tic': 'ALL'},
#   'model': <tensorflow.python.keras.engine.sequential.Sequential at 0x21110ca77c0>,
#   'history': <tensorflow.python.keras.callbacks.History at 0x21146976970>},
#  {'model_name': 'lstm_13',
#   'model_descr': {'units': [256, 256, 32, 1],
#    'dropout': None,
#    'loss': 'mean_squared_error',
#    'batch_size': 32,
#    'epochs': 25,
#    'tic': 'AAPL'},
#   'model': <tensorflow.python.keras.engine.sequential.Sequential at 0x2114dcdd100>,
#   'history': <tensorflow.python.keras.callbacks.History at 0x2114c8957c0>},
#  {'model_name': 'lstm_14',
#   'model_descr': {'units': [256, 256, 32, 1],
#    'dropout': None,
#    'loss': 'mean_squared_error',
#    'batch_size': 32,
#    'epochs': 25,
#    'tic': 'MSFT'},
#   'model': <tensorflow.python.keras.engine.sequential.Sequential at 0x2114c8b0490>,
#   'history': <tensorflow.python.keras.callbacks.History at 0x210e8927be0>},
#  {'model_name': 'lstm_15',
#   'model_descr': {'units': [256, 256, 32, 1],
#    'dropout': None,
#    'loss': 'mean_squared_error',
#    'batch_size': 32,
#    'epochs': 25,
#    'tic': 'SPY'},
#   'model': <tensorflow.python.keras.engine.sequential.Sequential at 0x210e8a54100>,
#   'history': <tensorflow.python.keras.callbacks.History at 0x20548c81760>},
#  {'model_name': 'lstm_16',
#   'model_descr': {'units': [256, 256, 32, 1],
#    'dropout': None,
#    'loss': 'mean_squared_error',
#    'batch_size': 32,
#    'epochs': 25,
#    'tic': 'ALL'},
#   'model': <tensorflow.python.keras.engine.sequential.Sequential at 0x208677966d0>,
#   'history': <tensorflow.python.keras.callbacks.History at 0x21081e15a00>},
#  {'model_name': 'lstm_17',
#   'model_descr': {'units': [128, 128, 32, 1],
#    'dropout': None,
#    'loss': 'mean_squared_error',
#    'batch_size': 32,
#    'epochs': 25,
#    'tic': 'ALL'},
#   'model': <tensorflow.python.keras.engine.sequential.Sequential at 0x21081da1070>,
#   'history': <tensorflow.python.keras.callbacks.History at 0x2108225f4c0>},
#  {'model_name': 'lstm_18',
#   'model_descr': {'units': [256, 128, 32, 1],
#    'dropout': None,
#    'loss': 'mean_squared_error',
#    'batch_size': 32,
#    'epochs': 25,
#    'tic': 'ALL'},
#   'model': <tensorflow.python.keras.engine.sequential.Sequential at 0x20950111bb0>,
#   'history': <tensorflow.python.keras.callbacks.History at 0x20c2d0a05b0>},
#  {'model_name': 'lstm_19',
#   'model_descr': {'units': [256, 256, 32, 1],
#    'dropout': None,
#    'loss': 'mean_squared_error',
#    'batch_size': 32,
#    'epochs': 25,
#    'tic': 'ALL'},
#   'model': <tensorflow.python.keras.engine.sequential.Sequential at 0x20ab5e58a30>,
#   'history': <tensorflow.python.keras.callbacks.History at 0x2114c8a6fa0>},
#  {'model_name': 'lstm_20',
#   'model_descr': {'units': [512, 128, 32, 1],
#    'dropout': None,
#    'loss': 'mean_squared_error',
#    'batch_size': 32,
#    'epochs': 25,
#    'tic': 'ALL'},
#   'model': <tensorflow.python.keras.engine.sequential.Sequential at 0x20f4a165550>,
#   'history': <tensorflow.python.keras.callbacks.History at 0x20b5d607b80>},
#  {'model_name': 'lstm_21',
#   'model_descr': {'units': [512, 256, 32, 1],
#    'dropout': None,
#    'loss': 'mean_squared_error',
#    'batch_size': 32,
#    'epochs': 25,
#    'tic': 'ALL'},
#   'model': <tensorflow.python.keras.engine.sequential.Sequential at 0x208d597c100>,
#   'history': <tensorflow.python.keras.callbacks.History at 0x20c8d743e50>},
#  {'model_name': 'lstm_22',
#   'model_descr': {'units': [512, 512, 64, 1],
#    'dropout': None,
#    'loss': 'mean_squared_error',
#    'batch_size': 32,
#    'epochs': 25,
#    'tic': 'ALL'},
#   'model': <tensorflow.python.keras.engine.sequential.Sequential at 0x20c8d75c370>,
#   'history': <tensorflow.python.keras.callbacks.History at 0x20501b03b50>}]

# %% [markdown]
# ### Learning Curves

# %%
def plot_history(model_name, history):
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    plt.title(model_name)
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.yscale("log")
    plt.ylabel('MAE')
    plt.xlabel('epoch')
    plt.show()

# %%
# %matplotlib inline

for model in model_list:
    plot_history(model['model_name'], model['history'])

# %% [markdown]
# ## Analysis and Prediction

# %% [markdown]
# ### Multiple Stocks Prediction

# %%
def retrain(x_train, y_train, model, batch_size=1, epochs=1):
    history = model.fit(x_train, y_train, batch_size = batch_size, epochs=epochs)
    return history

def inverse_transform_y(y_data, scaler, y_col_idx):
    a = np.zeros(shape=(len(y_data), scaler.scale_.shape[0]))
    a[:,y_col_idx]=y_data[:,0]
    return np.exp(scaler.inverse_transform(a)[:,0])

def predict(x, y_val, model):
    y = model.predict(x)
    mse = np.mean(((np.array(y).flatten() - np.array(y_val).flatten()) ** 2))
    return y, mse

# %%
# %%time

def loop_evaluation(model_list):
    for model in model_list:
        
        x_train, y_train = merge_tic(x_train_dict, y_train_dict)
        x_test, y_test = merge_tic(x_test_dict, y_test_dict)
        
        y_train_predict, train_mse = predict(x_train, y_train, model['model'])
        y_test_predict, test_mse = predict(x_test, y_test, model['model'])

        if 'y_train_predict' in model:
            del model['y_train_predict']
        if 'train_rmse' in model:
            del model['train_rmse']
        if 'y_test_predict' in model:
            del model['y_test_predict']
        if 'test_rmse' in model:
            del model['test_rmse']
        model['train_mse']= train_mse
        model['test_mse'] = test_mse
        
        print("model: {}\t train mse: {}\t test mse: {}\n".format(model['model_name'], train_mse, test_mse))
loop_evaluation(model_list)
# Out:
# model: lstm_0	 train mse: 2.2621063868606854e-05	 test mse: 2.9028550891827284e-05
#
# model: lstm_1	 train mse: 2.5470369550489275e-05	 test mse: 4.765304326697442e-05
#
# model: lstm_2	 train mse: 4.786081937442599e-05	 test mse: 0.0001338817417905208
#
# model: lstm_3	 train mse: 0.00011048611180343358	 test mse: 9.205519600496277e-05
#
# model: lstm_4	 train mse: 3.226933239089926e-05	 test mse: 5.331697337468461e-05
#
# model: lstm_5	 train mse: 3.0771708862721574e-05	 test mse: 4.1014176963702295e-05
#
# model: lstm_6	 train mse: 2.4740186506661166e-05	 test mse: 3.8660313131542525e-05
#
# model: lstm_7	 train mse: 3.807541987540736e-05	 test mse: 5.7324909807736265e-05
#
# model: lstm_8	 train mse: 2.7351442492085944e-05	 test mse: 4.4443126476742546e-05
#
# model: lstm_9	 train mse: 2.548737505907922e-05	 test mse: 4.999698042762599e-05
#
# model: lstm_10	 train mse: 2.3206285893968768e-05	 test mse: 3.2000345617692714e-05
#
# model: lstm_11	 train mse: 2.246048312268925e-05	 test mse: 3.097505691913837e-05
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <timed exec> in <module>
#
# <timed exec> in loop_evaluation(model_list)
#
# <ipython-input-110-0889bd060dab> in merge_tic(x_dict, y_dict)
#       3     Merge Tickers to one dataset
#       4     """
# ----> 5     x = np.concatenate(tuple(x_dict.values()), axis=0)
#       6     y = np.concatenate(tuple(y_dict.values()), axis=0)
#       7     return x, y
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# MemoryError: Unable to allocate 1.39 GiB for an array with shape (98511, 90, 21) and data type float64

# %% [markdown]
# ### Single Stock Prediction

# %% [markdown]
# Select SPY as the sp index represent ticker, and trying to use model predict SPY ticker

# %% [markdown]
# #### Model Retrain with Single Stock Data

# %% [markdown]
# The above models already capture all tickers pattern. However, to fit one ticker better with above model, clone an model, and use SPY ticker training dataset to retrain the clone model.

# %%
x_train, y_train, x_test, y_test = x_train_dict['SPY'], y_train_dict['SPY'], x_test_dict['SPY'], y_test_dict['SPY']
model = tf.keras.models.clone_model(models['simple_lstm0'])
retrain(x_train, y_train, model, batch_size=16, epochs=5)
# Out:
# Epoch 1/3
# 147/147 [==============================] - 3s 21ms/step - loss: 4.9170e-05
# Epoch 2/3
# 147/147 [==============================] - 3s 22ms/step - loss: 4.5739e-05
# Epoch 3/3
# 147/147 [==============================] - 3s 21ms/step - loss: 4.5542e-05

# %% [markdown]
# #### Prediction and Inverse Transform Result

# %%
y_train_predict, _ = predict(x_train, y_train, model)
y_test_predict, _ = predict(x_test, y_test, model)

train_predict = inverse_transform_y(y_train_predict, scalers['SPY'], y_col_idx=0)
train_val = inverse_transform_y(np.reshape(y_train, (y_train.shape[0], 1 )), scalers['SPY'], y_col_idx=0)
test_predict = inverse_transform_y(y_test_predict, scalers['SPY'], y_col_idx=0)
test_val = inverse_transform_y(np.reshape(y_test, (y_test.shape[0], 1 )), scalers['SPY'], y_col_idx=0)
# Out:
# 0.17882039737528269
# 0.04332059302120271

# %% [markdown]
# #### Display A Continouos Data

# %%
train = SPY[input_width + shift - 1 : len(x_train) + input_width + shift - 1].copy()
train['predict']=train_predict
train['val']=train_val
valid = SPY[len(x_train) + input_width + shift - 1 :].copy()
valid['predict'] = test_predict
valid['val']=test_val

# %%
# %matplotlib inline

# Visualize the data
plt.figure(figsize=(16,6))
plt.title('Model')
plt.xlabel('Date', fontsize=10)
plt.ylabel('Close Price USD ($)', fontsize=10)
plt.plot(train['val'], label='train_val')
plt.plot(train['predict'], label='train_predict')
plt.plot(valid['val'], label='test_val')
plt.plot(valid['predict'], label='test_predict')
# plt.plot(train[['val','predict']])
# plt.plot(valid[['val','predict']])
# plt.legend(['Train', 'Train_Predict' 'Test', 'Test_Predict'], loc='lower right')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %% [markdown]
# ## Stock Trading

# %% [markdown]
# ### Trading Strategy

# %% [markdown]
# A simple strategy base on the prediction result:
# - condition1: if predict price lower than current price, hold cash
# - condition2: if predict price higher than or equal to current price, hold share

# %%
def trading(prev_price, real_price, predict_price):
    """
    Trading Logic
    """
    prev_portfolio = 1.0
    records = [prev_portfolio]
    for i in range(len(real_price)):
        if predict_price[i] > prev_price[i]:
            portfolio = (prev_portfolio / prev_price[i]) * real_price[i]
        else:
            portfolio = prev_portfolio
        prev_portfolio = portfolio
        records.append(prev_portfolio)
    return records

# %%
def gen_prev_price(begin_price, real_price):
    """
    Generate One Previous Value Point
    """
    prev_price=real_price.copy()[:-1]
    return np.insert(prev_price, 0, begin_price)

prev_val = gen_prev_price(train_val[-1], test_val)
records=trading(prev_val, test_val, test_predict)

# %% [markdown]
# ### Trading Performance Visualization

# %%
# %matplotlib inline

# Visualize the data
plt.figure(figsize=(16,6))
plt.title('Trading')
plt.xlabel('Date', fontsize=10)
plt.ylabel('Close Price USD ($)', fontsize=10)
plt.plot(test_val, label='test_val')
plt.plot(test_predict, label='test_predict')
plt.plot(records[1:]*prev_val, label='portfolio_return')
# plt.plot(train[['val','predict']])
# plt.plot(valid[['val','predict']])
# plt.legend(['Train', 'Train_Predict' 'Test', 'Test_Predict'], loc='lower right')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()
