# %% [markdown]
# # LSTM Prediction ans Simple Trading

# %% [markdown]
# # Table of Contents
#
# - [Problem Definition](#Problem-Definition)
# - [Dataset](#Dataset)
# - [Feature Engineering](#Feature-Engineering)
# 	- [Technical Indicators](#Technical-Indicators)
# 	- [Example Data](#Example-Data)
# 	- [Data Scaling](#Data-Scaling)
# 	- [Time Window Conversion](#Time-Window-Conversion)
# - [Modeling](#Modeling)
# 	- [Hyperparameters](#Hyperparameters)
# 	- [Learning Curves](#Learning-Curves)
# - [Analysis and Prediction](#Analysis-and-Prediction)
# 	- [Multiple Stocks Prediction](#Multiple-Stocks-Prediction)
# 	- [Single Stock Prediction](#Single-Stock-Prediction)
# 	- [Dependencies](#Dependencies)
# - [Stock Trading](#Stock-Trading)
# 	- [Trading Strategy](#Trading-Strategy)
# 	- [Trading Performance](#Trading-Performance)

# %% [markdown]
# ## Problem Definition

# %% [markdown]
# The project target is to use machine learning method to investigate the applying possibility of market trading.
#
# In LSTM Prediction and Simple Trading subproject, here we discuss a simple approach use general Deep Learning method to predict market and apply the prediction result to a simple trading strategy to evaluate the portfolio performance.

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import datetime
import time
from pprint import pprint
import itertools
import seaborn as sns
import tkinter
from sklearn.preprocessing import MinMaxScaler
from sklearn.utils import shuffle
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
import tensorflow as tf
from tensorflow.keras.losses import LogCosh, Huber

import IPython
import IPython.display

# %matplotlib inline
from rl.config import config
from rl.marketdata.yahoodownloader import YahooDownloader
from rl.preprocessing.preprocessors import FeatureEngineer
from rl.preprocessing.data import data_split
from rl.trade.backtest import backtest_stats, backtest_plot, get_daily_return, get_baseline
# Out:
# D:\InstalledSoftware\anaconda3\envs\py37-python-notebook\lib\site-packages\pyfolio\pos.py:26: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(

# %%
import os
if not os.path.exists("./" + config.DATA_SAVE_DIR):
    os.makedirs("./" + config.DATA_SAVE_DIR)
if not os.path.exists("./" + config.TRAINED_MODEL_DIR):
    os.makedirs("./" + config.TRAINED_MODEL_DIR)
if not os.path.exists("./" + config.TENSORBOARD_LOG_DIR):
    os.makedirs("./" + config.TENSORBOARD_LOG_DIR)
if not os.path.exists("./" + config.RESULTS_DIR):
    os.makedirs("./" + config.RESULTS_DIR)

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Dataset

# %% [markdown]
# Here is the dataset configuration:

# %%
# from config.py start_date is a string
start_date = config.START_DATE
# from config.py end_date is a string
end_date = config.END_DATE
# from config.py split_date is a string
split_date = config.SPLIT_DATE
# config target ticker
target_ticker = config.SP500_20_TICKER.copy()
target_ticker.extend(['SPY'])
# config tech_indicator_list
tech_indicator_list = config.TECHNICAL_INDICATORS_LIST
print("training period: {}-{}, testing period: {}-{}\n".format(start_date, split_date, split_date, end_date))
print("target ticker list:\n {}\n".format(target_ticker))
print("tech_indicator_list:\n {}\n".format(tech_indicator_list))
# Out:
# training period: 2000-01-01-2019-01-01, testing period: 2019-01-01-2021-01-01
#
# target ticker list:
#  ['AAPL', 'MSFT', 'AMZN', 'BRK-B', 'JPM', 'JNJ', 'UNH', 'HD', 'PG', 'NVDA', 'DIS', 'BAC', 'CMCSA', 'XOM', 'VZ', 'T', 'ADBE', 'PFE', 'CSCO', 'INTC', 'SPY']
#
# tech_indicator_list:
#  ['macd', 'boll_ub', 'boll_lb', 'rsi_10', 'rsi_20', 'cci_10', 'cci_20', 'dx_30', 'close_20_sma', 'close_60_sma', 'close_120_sma', 'close_20_ema', 'close_60_ema', 'close_120_ema']

# %%
df = YahooDownloader(start_date = start_date,
                     end_date = end_date,
                     ticker_list = target_ticker).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (110964, 8)

# %%
df.sort_values(['date','tic'],ignore_index=True).head()
# Out:
#          date       open       high        low      close       volume    tic  \
# 0  2000-01-03   0.936384   1.004464   0.907924   0.859423  535796800.0   AAPL
# 1  2000-01-03  16.812500  16.875000  16.062500  16.274673    7384400.0   ADBE
# 2  2000-01-03  81.500000  89.562500  79.046875  89.375000   16117600.0   AMZN
# 3  2000-01-03  25.125000  25.125000  24.000000  13.952057   13705800.0    BAC
# 4  2000-01-03  36.500000  36.580002  34.820000  35.299999     875000.0  BRK-B
#
#    day
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Add Technical Indicators

# %% [markdown]
# The feature engineering step would general technical indicators according to the original ticker's information.

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    tech_indicator_list = tech_indicator_list,
                    use_turbulence=True,
                    user_defined_feature = False)

processed = fe.preprocess_data(df)

processed.head()
# Out:
# Successfully added technical indicators
# Successfully added turbulence index
#          date       open       high        low      close       volume    tic  \
# 0  2000-01-03   0.936384   1.004464   0.907924   0.859423  535796800.0   AAPL
# 1  2000-01-03  16.812500  16.875000  16.062500  16.274673    7384400.0   ADBE
# 2  2000-01-03  81.500000  89.562500  79.046875  89.375000   16117600.0   AMZN
# 3  2000-01-03  25.125000  25.125000  24.000000  13.952057   13705800.0    BAC
# 4  2000-01-03  36.500000  36.580002  34.820000  35.299999     875000.0  BRK-B
#
#    day  macd   boll_ub   boll_lb  rsi_10  rsi_20     cci_10     cci_20  dx_30  \
# 0    0   0.0  0.925665  0.720723     0.0     0.0 -66.666667 -66.666667  100.0
# 1    0   0.0  0.925665  0.720723     0.0     0.0 -66.666667 -66.666667  100.0
# 2    0   0.0  0.925665  0.720723     0.0     0.0 -66.666667 -66.666667  100.0
# 3    0   0.0  0.925665  0.720723     0.0     0.0 -66.666667 -66.666667  100.0
# 4    0   0.0  0.925665  0.720723     0.0     0.0 -66.666667 -66.666667  100.0
#
#    close_20_sma  close_60_sma  close_120_sma  close_20_ema  close_60_ema  \
# 0      0.859423      0.859423       0.859423      0.859423      0.859423
# 1     16.274673     16.274673      16.274673     16.274673     16.274673
# 2     89.375000     89.375000      89.375000     89.375000     89.375000
# 3     13.952057     13.952057      13.952057     13.952057     13.952057
# 4     35.299999     35.299999      35.299999     35.299999     35.299999
#
#    close_120_ema  turbulence
# 0       0.859423         0.0
# 1      16.274673         0.0
# 2      89.375000         0.0
# 3      13.952057         0.0
# 4      35.299999         0.0

# %%
list_ticker = processed["tic"].unique().tolist()
list_date = list(pd.date_range(processed['date'].min(),processed['date'].max()).astype(str))
combination = list(itertools.product(list_date,list_ticker))

processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(processed,on=["date","tic"],how="left")
processed_full = processed_full[processed_full['date'].isin(processed['date'])]
processed_full = processed_full.sort_values(['date','tic'])
processed_full = processed_full.fillna(0)

processed_full.sort_values(['date','tic'], ignore_index=True).head(10)
# Out:
#          date    tic       open       high        low      close       volume  \
# 0  2000-01-03   AAPL   0.936384   1.004464   0.907924   0.859423  535796800.0
# 1  2000-01-03   ADBE  16.812500  16.875000  16.062500  16.274673    7384400.0
# 2  2000-01-03   AMZN  81.500000  89.562500  79.046875  89.375000   16117600.0
# 3  2000-01-03    BAC  25.125000  25.125000  24.000000  13.952057   13705800.0
# 4  2000-01-03  BRK-B  36.500000  36.580002  34.820000  35.299999     875000.0
# 5  2000-01-03  CMCSA  16.145832  16.333332  15.062500  12.189544    2333700.0
# 6  2000-01-03   CSCO  54.968750  55.125000  51.781250  40.118656   53076000.0
# 7  2000-01-03    DIS  28.855125  29.533344  28.361876  23.115248    8402230.0
# 8  2000-01-03     HD  68.625000  69.187500  63.812500  42.563168   12030800.0
# 9  2000-01-03   INTC  41.632812  43.687500  41.625000  27.002798   57710200.0
#
#    day  macd   boll_ub   boll_lb  rsi_10  rsi_20     cci_10     cci_20  dx_30  \
# 0  0.0   0.0  0.925665  0.720723     0.0     0.0 -66.666667 -66.666667  100.0
# 1  0.0   0.0  0.925665  0.720723     0.0     0.0 -66.666667 -66.666667  100.0
# 2  0.0   0.0  0.925665  0.720723     0.0     0.0 -66.666667 -66.666667  100.0
# 3  0.0   0.0  0.925665  0.720723     0.0     0.0 -66.666667 -66.666667  100.0
# 4  0.0   0.0  0.925665  0.720723     0.0     0.0 -66.666667 -66.666667  100.0
# 5  0.0   0.0  0.925665  0.720723     0.0     0.0 -66.666667 -66.666667  100.0
# 6  0.0   0.0  0.925665  0.720723     0.0     0.0 -66.666667 -66.666667  100.0
# 7  0.0   0.0  0.925665  0.720723     0.0     0.0 -66.666667 -66.666667  100.0
# 8  0.0   0.0  0.925665  0.720723     0.0     0.0 -66.666667 -66.666667  100.0
# 9  0.0   0.0  0.925665  0.720723     0.0     0.0 -66.666667 -66.666667  100.0
#
#    close_20_sma  close_60_sma  close_120_sma  close_20_ema  close_60_ema  \
# 0      0.859423      0.859423       0.859423      0.859423      0.859423
# 1     16.274673     16.274673      16.274673     16.274673     16.274673
# 2     89.375000     89.375000      89.375000     89.375000     89.375000
# 3     13.952057     13.952057      13.952057     13.952057     13.952057
# 4     35.299999     35.299999      35.299999     35.299999     35.299999
# 5     12.189544     12.189544      12.189544     12.189544     12.189544
# 6     40.118656     40.118656      40.118656     40.118656     40.118656
# 7     23.115248     23.115248      23.115248     23.115248     23.115248
# 8     42.563168     42.563168      42.563168     42.563168     42.563168
# 9     27.002798     27.002798      27.002798     27.002798     27.002798
#
#    close_120_ema  turbulence
# 0       0.859423         0.0
# 1      16.274673         0.0
# 2      89.375000         0.0
# 3      13.952057         0.0
# 4      35.299999         0.0
# 5      12.189544         0.0
# 6      40.118656         0.0
# 7      23.115248         0.0
# 8      42.563168         0.0
# 9      27.002798         0.0

# %% [markdown]
# ### Example Data

# %%
SPY=processed_full[processed_full['tic']=='SPY']
SPY=SPY.reset_index(drop=True)

# %matplotlib inline

plt.figure(figsize=(16,6))
plt.title('Close Price History', fontsize=20)
plt.plot(SPY['close'])
plt.xlabel('date', fontsize=16)
plt.ylabel('Close Price USD ($)', fontsize=16)
plt.show()

# %% [markdown]
# ### Data Scaling

# %% [markdown]
# #### Logarithmic Conversion

# %% [markdown]
# During our previous training experience, we found many stock cannot fit well as the price goes high, but in historical pricing range, the directly trained model works acceptable. And then, we look back to the original dataset, there are some concerns training historical data to predict future.
# - the future price generally growth as company and total market growth, using the historical price related feature predict future somehow like using data predict out of training feature space points. As well as other patterns may only exist in near months dataset. Our solution is adopt rolling prediction method to predict future (in this project is 2019-01-01 to 2021-01-01) with near months data.
#
# Selected the close price from above example ticker, we could make some simple fit with linear and no-linear regression as following.
#
# Obviously, the sp index pricing follow the expenitial tendency, same as pricing direvative technical indicator.
#
# - the total market price increase more close to expnential than linear as following shows, if we could convert the no-linear data to a easier acceptable data by Deep Nerual Network, it would help to boost the model performance.

# %%
def linear_polyfit(ticker, ):
    coefficients=np.polyfit(np.array(range(len(ticker))), np.array(ticker['close']), 1)
    poly = np.poly1d(coefficients)
    poly_x = np.array(range(len(SPY)))
    poly_y = poly(poly_x)
    return poly_x, poly_y

def exp_polyfit(ticker, ):
    coefficients=np.polyfit(np.array(range(len(ticker))), np.log(np.array(ticker['close'])), 1)
    poly = np.poly1d(coefficients)
    poly_x = np.array(range(len(SPY)))
    poly_y = np.exp(poly(poly_x))
    return poly_x, poly_y

# %%
# %matplotlib inline

_, poly_y = linear_polyfit(SPY)
plt.figure()
plt.title('Close Price Linear Fit')
plt.plot(SPY['close'], label='close_price')
plt.plot(poly_y, label='linear_fit')
plt.xlabel('Date')
plt.ylabel('Close Price USD ($)')
plt.show()

_, poly_y = exp_polyfit(SPY)
plt.figure()
plt.title('Close Price Exp Fit')
plt.plot(SPY['close'], label='close_price')
plt.plot(poly_y, label='log_fit')
plt.xlabel('Date')
plt.yscale("log")
plt.ylabel('Close Price')
plt.show()

# %% [markdown]
# Here are several feature columns could be logarithmic convert.

# %%
# log convert price related values
log_feature_columns = ['close', 'open', 'high', 'low', 'boll_ub', 'boll_lb',
       'close_20_sma', 'close_60_sma', 'close_120_sma', 'close_20_ema',
       'close_60_ema', 'close_120_ema']

def log_convert(data, log_feature_columns):
    return data.apply(lambda x: np.log(x) if x.name in log_feature_columns else x)

processed_full=log_convert(processed_full, log_feature_columns)

# %% [markdown]
# #### Scaling Conversion

# %%
# Training feature_columns
feature_columns = ['close', 'open', 'high', 'low', 'volume', 'day', 'macd',
       'boll_ub', 'boll_lb', 'rsi_10', 'rsi_20', 'cci_10', 'cci_20', 'dx_30',
       'close_20_sma', 'close_60_sma', 'close_120_sma', 'close_20_ema',
       'close_60_ema', 'close_120_ema', 'turbulence']

# %%
def scale_df(df, feature_columns):
    tics = df.tic.unique()
    scalers = {}
    dataset = {}
    scaled_dataset = {}
    for tic in tics:
        dataset[tic] = df[df['tic']==tic].filter(feature_columns).values
        # Most of stock long term increase, so here may have some skew, reserve the range not full.
        scalers[tic] = MinMaxScaler(feature_range=(0.2,0.8))
        scaled_dataset[tic] = scalers[tic].fit_transform(dataset[tic])
    return scalers, dataset, scaled_dataset
scalers, dataset, scaled_dataset = scale_df(processed_full, feature_columns)

# %% [markdown]
# ### Time Window Conversion

# %% [markdown]
# Our target is convert original data to a continuous time series dataset. Here is the time series slices parameters define. The original data would be convert to continuous time slice dataset

# %%
# Time Series Data Hyperparameter Define:
shift = 1 # the target y offset from last x time series gap
input_width = 90 # the x input time windows width, per quarter
train_idx = 4779 # get date from 2000-01-01 to 2018-12-31

# %%
# Create the training data set 
# Create the scaled training data set
# Split the data into x_train and y_train data sets
def data_window_split(df, train_idx, input_width, shift):
    """
    Split dataset to time series windows
    df: data frame
    train_len: training dataset length
    input_width: training time series length
    shift: offset between x and y
    """
    x_train = []
    y_train = []
    x_test = []
    y_test = []
    for i in range(input_width - 1, len(df) - shift):
        if i <= train_idx:
            x_train.append(df[i - input_width + 1: i + 1, :])
            y_train.append(df[i + shift, 0])
        else:
            x_test.append(df[i - input_width + 1: i + 1, :])
            y_test.append(df[i + shift, 0])
    
    x_train, y_train, x_test, y_test = np.array(x_train), np.array(y_train), np.array(x_test), np.array(y_test)

    return x_train, y_train, x_test, y_test

def data_prepare(full_stock_data, train_idx, input_width, shift):
    """
    data_prepare: prepare dataset by ticker.
    """
    x_train_dict = {}
    y_train_dict = {}
    x_test_dict = {}
    y_test_dict = {}
    for k in full_stock_data.keys():
        data = full_stock_data[k]
        x_train_dict[k], y_train_dict[k], x_test_dict[k], y_test_dict[k] = data_window_split(data, train_idx, input_width, shift)
        
        print(k, '\t', x_train_dict[k].shape, y_train_dict[k].shape, x_test_dict[k].shape, y_test_dict[k].shape)
    return x_train_dict, y_train_dict, x_test_dict, y_test_dict

x_train_dict, y_train_dict, x_test_dict, y_test_dict = data_prepare(scaled_dataset, train_idx, input_width, shift)
# Out:
# AAPL 	 (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# ADBE 	 (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# AMZN 	 (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# BAC 	 (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# BRK-B 	 (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# CMCSA 	 (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# CSCO 	 (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# DIS 	 (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# HD 	 (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# INTC 	 (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# JNJ 	 (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# JPM 	 (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# MSFT 	 (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# NVDA 	 (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# PFE 	 (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# PG 	 (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# SPY 	 (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# T 	 (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# UNH 	 (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# VZ 	 (4691, 90, 21) (4691,) (503, 90, 21) (503,)
# XOM 	 (4691, 90, 21) (4691,) (503, 90, 21) (503,)

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Baseline Model

# %% [markdown]
# #### Hyperparameters

# %% [markdown]
# In Hyperparameters searching, we try different model units, dropout rate, loss function, batch sizes, and if train in single stock per epoch or shuffle train all.
#
# - Units: units use 256 LSTM, 256 LSTM, 32 Dense, 1 Dense could give a relatively stable loss gradient descent.
#
# - dropout: if LSTM and Dense value not too large and consider the calculation resources' limitation, a better choice is don't dropout. The advantage is the NN could converge to a relative stable state fastly, and provent overfit by epoch estimate.
#
# - loss function: we tried several losses, a more reasonable loss is mean_absolute_percentage_error, the reason behind it is that in the market, our target is to fit the predict price to real price. Using percentage to represent predict result and real value relationship is more accuracy. For example, in 2000, AAPL price close to \\\$1.0, but in 2020 AAPL share price close to \\\$200.0, we hope to evenly fit the prediction to the real value instead of more sensitive in large number. In this scenario, the mean percentage error is ideally to use. And if considering the linear and derivative, maybe we could build our own loss at next step, to let the loss more smooth and linear derivatable when close to 0.
#
# - batch size: batch size would influence the model training speed as we hope to fully use GPU resource at each batch, but at the same time, if batch size too large, it would also cannot capture tiny pattern.
#
# - Single Stock or All stocks: build model for each stock, or train model on stock by stock, or shuffle data and train together is another potential optmized point. In the hyperparameters searching, All stock shuffle train performance is better. And if hope to predict single stock we could also retrain model for specific one.

# %%
units_option=[
    [128, 128, 32], 
    [256, 256, 64], 
    [512, 512, 64], 
]
units=[256,256,32]
dropout_option=[None,0.2]
dropout=None
loss_option=['mean_squared_error', 'mean_absolute_percentage_error', 'huber_loss', 'log_cosh']
loss='mean_absolute_percentage_error'
batch_size_option=[32, 128, 512]
batch_size=128
tic_option=['SPY', 'ALL']
tic='ALL'

# %%
def merge_tic(x_dict, y_dict):
    """
    Merge Tickers to one dataset
    """
    x = np.concatenate(tuple(x_dict.values()), axis=0)
    y = np.concatenate(tuple(y_dict.values()), axis=0)
    return x, y

# Build the LSTM model
def build_simple_lstm(units, dropout=None, optimizer='adam', loss='mean_squared_error'):
    model = Sequential()
    model.add(LSTM(units[0], return_sequences=True, input_shape=(input_width, len(feature_columns))))
    if dropout and dropout > 0.0:
        model.add(Dropout(rate=dropout))
    model.add(LSTM(units[1], return_sequences=False))
    if dropout and dropout > 0.0:
        model.add(Dropout(rate=dropout))
    model.add(Dense(units[2]))
    if dropout and dropout > 0.0:
        model.add(Dropout(rate=dropout))
    model.add(Dense(1))
    model.compile(
        optimizer=optimizer, loss=loss, metrics=[tf.metrics.MeanAbsoluteError(), tf.metrics.MeanAbsolutePercentageError(), tf.metrics.MeanSquaredError()]
    )
    return model

def model_fit(
    x_train, 
    y_train, 
    model, 
    batch_size=1, 
    epochs=1, 
    validation_split=0.1,
    shuffle_split=True,
):
    if shuffle_split:
        x_train, y_train = shuffle(x_train, y_train)
    history = model.fit(
        x_train, 
        y_train, 
        batch_size = batch_size, 
        epochs=epochs, 
        validation_split=validation_split,
        verbose=1
    )
    return history

def model_fit_merge_tic(
    x_train_dict, 
    y_train_dict, 
    model, 
    batch_size=1, 
    epochs=1, 
    validation_split=0.1,
    shuffle_split=True,
):
    x_train, y_train = merge_tic(x_train_dict, y_train_dict)
    if shuffle_split:
        x_train, y_train = shuffle(x_train, y_train)
    history = model.fit(
        x_train, 
        y_train, 
        batch_size = batch_size, 
        epochs=epochs, 
        validation_split=validation_split,
        verbose=1
    )
    return history

def model_fit_per_tic(x_train_dict, y_train_dict, model, batch_size=1, epochs=1, validation_split=0.1, shuffle_split=True,):
    loss_r=[]
    val_loss_r=[]
    for i in range(epochs):
        print("======== epochs: {} ========".format(i))
        loss = []
        val_loss = []
        for k in x_train_dict:
            x_train, y_train = x_train_dict[k], y_train_dict[k]
            if shuffle_split:
                x_train, y_train = shuffle(x_train, y_train)
            history = model.fit(x_train, y_train, batch_size = batch_size, epochs=1, validation_split=validation_split,verbose=1)
            loss.append(history.history['loss'])
            val_loss.append(history.history['val_loss'])
        loss_r.append(np.mean(loss))
        val_loss_r.append(np.mean(val_loss))
    history.history['loss'] = loss_r
    history.history['val_loss'] = val_loss_r
    return history

# %%
def build_and_fit(idx, units, dropout, loss, batch_size, epochs, tic):
    model_name = 'lstm_{}'.format(idx)
    model_descr = {
        'units': units,
        'dropout': dropout,
        'loss': loss,
        'batch_size': batch_size,
        'epochs': epochs,
        'tic': tic
    }
    print("\n======== Model: {} ========\ndescription: {}\n".format(model_name, model_descr))
    model = build_simple_lstm(
        units=units, 
        dropout=dropout, 
        optimizer='adam', 
        loss=loss
    )
    if tic == 'ALL':
        history = model_fit_merge_tic(x_train_dict, y_train_dict, model, batch_size=batch_size, epochs=epochs)
    else:
        history = model_fit(x_train_dict[tic], y_train_dict[tic], model, batch_size=batch_size, epochs=epochs)
    ret = {
        'model_name': model_name,
        'model_descr': model_descr,
        'model': model,
        'history': history
    }
    return ret

def hyperparam_search(model_list, units_option, dropout_option, loss_option, tic_option, epochs=8):
    idx=0
    model_list.append(build_and_fit(idx, units, dropout, loss, batch_size, epochs, tic))
    idx+=1
    for d in dropout_option:
        if d == dropout:
            continue
        model_list.append(build_and_fit(idx, units, d, loss, batch_size, epochs, tic))
        idx+=1
    for l in loss_option:
        if l == loss:
            continue
        model_list.append(build_and_fit(idx, units, dropout, l, batch_size, epochs, tic))
        idx+=1
    for b in batch_size_option:
        if b == batch_size:
            continue
        model_list.append(build_and_fit(idx, units, dropout, loss, b, epochs, tic))
        idx+=1
    for t in tic_option:
        if t == tic:
            continue
        model_list.append(build_and_fit(idx, units, dropout, loss, batch_size, epochs, t))
        idx+=1
    for u in units_option:
        if u == units:
            continue
        model_list.append(build_and_fit(idx, u, dropout, loss, batch_size, epochs, tic))
        idx+=1
    return model_list

# %%
model_list=[]
hyperparam_search(model_list, units_option, dropout_option, loss_option, tic_option, epochs=30)

time.sleep(5)
IPython.display.clear_output()
# Out:
# ======== Model: lstm_0 ========
# description: {'units': [256, 256, 32], 'dropout': None, 'loss': 'mean_absolute_percentage_error', 'batch_size': 128, 'epochs': 30, 'tic': 'ALL'}
#
# Epoch 1/30
# 693/693 [==============================] - 24s 30ms/step - loss: 10.1468 - mean_absolute_error: 0.0459 - mean_absolute_percentage_error: 10.1468 - mean_squared_error: 0.0240 - val_loss: 3.2989 - val_mean_absolute_error: 0.0135 - val_mean_absolute_percentage_error: 3.2989 - val_mean_squared_error: 2.4118e-04
# Epoch 2/30
# 693/693 [==============================] - 20s 29ms/step - loss: 2.2803 - mean_absolute_error: 0.0102 - mean_absolute_percentage_error: 2.2803 - mean_squared_error: 1.7584e-04 - val_loss: 1.6557 - val_mean_absolute_error: 0.0072 - val_mean_absolute_percentage_error: 1.6557 - val_mean_squared_error: 8.4455e-05
# Epoch 3/30
# 693/693 [==============================] - 20s 29ms/step - loss: 1.7249 - mean_absolute_error: 0.0077 - mean_absolute_percentage_error: 1.7249 - mean_squared_error: 9.9672e-05 - val_loss: 1.0900 - val_mean_absolute_error: 0.0046 - val_mean_absolute_percentage_error: 1.0900 - val_mean_squared_error: 4.2806e-05
# Epoch 4/30
# 693/693 [==============================] - 20s 29ms/step - loss: 1.4647 - mean_absolute_error: 0.0065 - mean_absolute_percentage_error: 1.4647 - mean_squared_error: 7.2661e-05 - val_loss: 0.9801 - val_mean_absolute_error: 0.0041 - val_mean_absolute_percentage_error: 0.9801 - val_mean_squared_error: 3.4880e-05
# Epoch 5/30
# 693/693 [==============================] - 20s 29ms/step - loss: 1.3701 - mean_absolute_error: 0.0060 - mean_absolute_percentage_error: 1.3701 - mean_squared_error: 6.3418e-05 - val_loss: 1.7450 - val_mean_absolute_error: 0.0084 - val_mean_absolute_percentage_error: 1.7450 - val_mean_squared_error: 1.0028e-04
# Epoch 6/30
# 693/693 [==============================] - 21s 30ms/step - loss: 1.2778 - mean_absolute_error: 0.0056 - mean_absolute_percentage_error: 1.2778 - mean_squared_error: 5.6605e-05 - val_loss: 1.3267 - val_mean_absolute_error: 0.0058 - val_mean_absolute_percentage_error: 1.3267 - val_mean_squared_error: 5.3308e-05
# Epoch 7/30
# 693/693 [==============================] - 20s 29ms/step - loss: 1.2728 - mean_absolute_error: 0.0056 - mean_absolute_percentage_error: 1.2728 - mean_squared_error: 5.4685e-05 - val_loss: 1.3681 - val_mean_absolute_error: 0.0061 - val_mean_absolute_percentage_error: 1.3681 - val_mean_squared_error: 5.8972e-05
# Epoch 8/30
# 693/693 [==============================] - 20s 29ms/step - loss: 1.3077 - mean_absolute_error: 0.0058 - mean_absolute_percentage_error: 1.3077 - mean_squared_error: 5.6574e-05 - val_loss: 1.3825 - val_mean_absolute_error: 0.0061 - val_mean_absolute_percentage_error: 1.3825 - val_mean_squared_error: 5.6731e-05
# Epoch 9/30
# 693/693 [==============================] - 20s 29ms/step - loss: 1.2392 - mean_absolute_error: 0.0055 - mean_absolute_percentage_error: 1.2392 - mean_squared_error: 5.3393e-05 - val_loss: 0.8900 - val_mean_absolute_error: 0.0038 - val_mean_absolute_percentage_error: 0.8900 - val_mean_squared_error: 2.9613e-05
# Epoch 10/30
# 693/693 [==============================] - 20s 29ms/step - loss: 1.2015 - mean_absolute_error: 0.0053 - mean_absolute_percentage_error: 1.2015 - mean_squared_error: 4.8073e-05 - val_loss: 0.9535 - val_mean_absolute_error: 0.0040 - val_mean_absolute_percentage_error: 0.9535 - val_mean_squared_error: 3.1718e-05
# Epoch 11/30
# 693/693 [==============================] - 20s 29ms/step - loss: 1.1076 - mean_absolute_error: 0.0048 - mean_absolute_percentage_error: 1.1076 - mean_squared_error: 4.2241e-05 - val_loss: 0.9458 - val_mean_absolute_error: 0.0041 - val_mean_absolute_percentage_error: 0.9458 - val_mean_squared_error: 3.2191e-05
# Epoch 12/30
# 693/693 [==============================] - 20s 29ms/step - loss: 1.1878 - mean_absolute_error: 0.0052 - mean_absolute_percentage_error: 1.1878 - mean_squared_error: 4.7096e-05 - val_loss: 0.9564 - val_mean_absolute_error: 0.0041 - val_mean_absolute_percentage_error: 0.9564 - val_mean_squared_error: 3.3447e-05
# Epoch 13/30
# 693/693 [==============================] - 20s 29ms/step - loss: 1.2014 - mean_absolute_error: 0.0053 - mean_absolute_percentage_error: 1.2014 - mean_squared_error: 4.8675e-05 - val_loss: 1.0186 - val_mean_absolute_error: 0.0043 - val_mean_absolute_percentage_error: 1.0186 - val_mean_squared_error: 3.4002e-05
# Epoch 14/30
# 693/693 [==============================] - 20s 29ms/step - loss: 1.1260 - mean_absolute_error: 0.0049 - mean_absolute_percentage_error: 1.1260 - mean_squared_error: 4.3123e-05 - val_loss: 1.3325 - val_mean_absolute_error: 0.0056 - val_mean_absolute_percentage_error: 1.3325 - val_mean_squared_error: 5.0975e-05
# Epoch 15/30
# 693/693 [==============================] - 17s 25ms/step - loss: 1.0459 - mean_absolute_error: 0.0045 - mean_absolute_percentage_error: 1.0459 - mean_squared_error: 3.7896e-05 - val_loss: 0.8739 - val_mean_absolute_error: 0.0036 - val_mean_absolute_percentage_error: 0.8739 - val_mean_squared_error: 2.8057e-05
# Epoch 16/30
# 693/693 [==============================] - 16s 23ms/step - loss: 1.0689 - mean_absolute_error: 0.0046 - mean_absolute_percentage_error: 1.0689 - mean_squared_error: 3.8845e-05 - val_loss: 0.9019 - val_mean_absolute_error: 0.0038 - val_mean_absolute_percentage_error: 0.9019 - val_mean_squared_error: 2.9032e-05
# Epoch 17/30
# 693/693 [==============================] - 16s 23ms/step - loss: 0.9969 - mean_absolute_error: 0.0043 - mean_absolute_percentage_error: 0.9969 - mean_squared_error: 3.5415e-05 - val_loss: 1.1704 - val_mean_absolute_error: 0.0054 - val_mean_absolute_percentage_error: 1.1704 - val_mean_squared_error: 4.7265e-05
# Epoch 18/30
# 693/693 [==============================] - 16s 23ms/step - loss: 1.1267 - mean_absolute_error: 0.0049 - mean_absolute_percentage_error: 1.1267 - mean_squared_error: 4.1521e-05 - val_loss: 1.3791 - val_mean_absolute_error: 0.0058 - val_mean_absolute_percentage_error: 1.3791 - val_mean_squared_error: 5.1090e-05
# Epoch 19/30
# 693/693 [==============================] - 16s 23ms/step - loss: 1.0268 - mean_absolute_error: 0.0044 - mean_absolute_percentage_error: 1.0268 - mean_squared_error: 3.6538e-05 - val_loss: 0.8121 - val_mean_absolute_error: 0.0034 - val_mean_absolute_percentage_error: 0.8121 - val_mean_squared_error: 2.5485e-05
# Epoch 20/30
# 693/693 [==============================] - 16s 23ms/step - loss: 1.0706 - mean_absolute_error: 0.0046 - mean_absolute_percentage_error: 1.0706 - mean_squared_error: 3.8197e-05 - val_loss: 0.8268 - val_mean_absolute_error: 0.0035 - val_mean_absolute_percentage_error: 0.8268 - val_mean_squared_error: 2.6535e-05
# Epoch 21/30
# 693/693 [==============================] - 16s 23ms/step - loss: 0.9861 - mean_absolute_error: 0.0042 - mean_absolute_percentage_error: 0.9861 - mean_squared_error: 3.4547e-05 - val_loss: 0.8015 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 0.8015 - val_mean_squared_error: 2.5540e-05
# Epoch 22/30
# 693/693 [==============================] - 16s 23ms/step - loss: 1.0010 - mean_absolute_error: 0.0043 - mean_absolute_percentage_error: 1.0010 - mean_squared_error: 3.5009e-05 - val_loss: 0.8742 - val_mean_absolute_error: 0.0038 - val_mean_absolute_percentage_error: 0.8742 - val_mean_squared_error: 2.8361e-05
# Epoch 23/30
# 693/693 [==============================] - 16s 23ms/step - loss: 0.9903 - mean_absolute_error: 0.0043 - mean_absolute_percentage_error: 0.9903 - mean_squared_error: 3.4613e-05 - val_loss: 1.3838 - val_mean_absolute_error: 0.0064 - val_mean_absolute_percentage_error: 1.3838 - val_mean_squared_error: 6.0654e-05
# Epoch 24/30
# 693/693 [==============================] - 16s 24ms/step - loss: 1.0063 - mean_absolute_error: 0.0044 - mean_absolute_percentage_error: 1.0063 - mean_squared_error: 3.5729e-05 - val_loss: 1.0131 - val_mean_absolute_error: 0.0044 - val_mean_absolute_percentage_error: 1.0131 - val_mean_squared_error: 3.4205e-05
# Epoch 25/30
# 693/693 [==============================] - 16s 23ms/step - loss: 0.9758 - mean_absolute_error: 0.0042 - mean_absolute_percentage_error: 0.9758 - mean_squared_error: 3.3718e-05 - val_loss: 0.9292 - val_mean_absolute_error: 0.0038 - val_mean_absolute_percentage_error: 0.9292 - val_mean_squared_error: 2.9392e-05
# Epoch 26/30
# 693/693 [==============================] - 16s 23ms/step - loss: 0.9772 - mean_absolute_error: 0.0042 - mean_absolute_percentage_error: 0.9772 - mean_squared_error: 3.3320e-05 - val_loss: 1.9451 - val_mean_absolute_error: 0.0090 - val_mean_absolute_percentage_error: 1.9451 - val_mean_squared_error: 1.0341e-04
# Epoch 27/30
# 693/693 [==============================] - 16s 23ms/step - loss: 1.0207 - mean_absolute_error: 0.0044 - mean_absolute_percentage_error: 1.0207 - mean_squared_error: 3.5613e-05 - val_loss: 1.0105 - val_mean_absolute_error: 0.0044 - val_mean_absolute_percentage_error: 1.0105 - val_mean_squared_error: 3.3702e-05
# Epoch 28/30
# 693/693 [==============================] - 16s 23ms/step - loss: 0.8896 - mean_absolute_error: 0.0038 - mean_absolute_percentage_error: 0.8896 - mean_squared_error: 2.8630e-05 - val_loss: 0.7950 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 0.7950 - val_mean_squared_error: 2.4870e-05
# Epoch 29/30
# 693/693 [==============================] - 16s 23ms/step - loss: 0.9334 - mean_absolute_error: 0.0040 - mean_absolute_percentage_error: 0.9334 - mean_squared_error: 3.1313e-05 - val_loss: 0.9233 - val_mean_absolute_error: 0.0039 - val_mean_absolute_percentage_error: 0.9233 - val_mean_squared_error: 2.9677e-05
# Epoch 30/30
# 693/693 [==============================] - 16s 23ms/step - loss: 0.8763 - mean_absolute_error: 0.0037 - mean_absolute_percentage_error: 0.8763 - mean_squared_error: 2.8075e-05 - val_loss: 0.7764 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 0.7764 - val_mean_squared_error: 2.4076e-05
#
# ======== Model: lstm_1 ========
# description: {'units': [256, 256, 32], 'dropout': 0.2, 'loss': 'mean_absolute_percentage_error', 'batch_size': 128, 'epochs': 30, 'tic': 'ALL'}
#
# Epoch 1/30
# 693/693 [==============================] - 20s 24ms/step - loss: 14.0568 - mean_absolute_error: 0.0658 - mean_absolute_percentage_error: 14.0568 - mean_squared_error: 0.0159 - val_loss: 1.6570 - val_mean_absolute_error: 0.0070 - val_mean_absolute_percentage_error: 1.6570 - val_mean_squared_error: 9.4504e-05
# Epoch 2/30
# 693/693 [==============================] - 16s 23ms/step - loss: 5.4288 - mean_absolute_error: 0.0263 - mean_absolute_percentage_error: 5.4288 - mean_squared_error: 0.0013 - val_loss: 1.5242 - val_mean_absolute_error: 0.0066 - val_mean_absolute_percentage_error: 1.5242 - val_mean_squared_error: 8.1669e-05
# Epoch 3/30
# 693/693 [==============================] - 16s 23ms/step - loss: 3.9007 - mean_absolute_error: 0.0192 - mean_absolute_percentage_error: 3.9007 - mean_squared_error: 7.0862e-04 - val_loss: 1.3896 - val_mean_absolute_error: 0.0058 - val_mean_absolute_percentage_error: 1.3896 - val_mean_squared_error: 6.5983e-05
# Epoch 4/30
# 693/693 [==============================] - 16s 23ms/step - loss: 3.1209 - mean_absolute_error: 0.0154 - mean_absolute_percentage_error: 3.1209 - mean_squared_error: 4.8219e-04 - val_loss: 2.8649 - val_mean_absolute_error: 0.0138 - val_mean_absolute_percentage_error: 2.8649 - val_mean_squared_error: 2.5420e-04
# Epoch 5/30
# 693/693 [==============================] - 16s 23ms/step - loss: 2.9106 - mean_absolute_error: 0.0141 - mean_absolute_percentage_error: 2.9106 - mean_squared_error: 3.9932e-04 - val_loss: 1.0351 - val_mean_absolute_error: 0.0044 - val_mean_absolute_percentage_error: 1.0351 - val_mean_squared_error: 4.1410e-05
# Epoch 6/30
# 693/693 [==============================] - 16s 23ms/step - loss: 2.6935 - mean_absolute_error: 0.0130 - mean_absolute_percentage_error: 2.6935 - mean_squared_error: 3.4157e-04 - val_loss: 2.0844 - val_mean_absolute_error: 0.0083 - val_mean_absolute_percentage_error: 2.0844 - val_mean_squared_error: 1.0557e-04
# Epoch 7/30
# 693/693 [==============================] - 16s 23ms/step - loss: 2.6389 - mean_absolute_error: 0.0126 - mean_absolute_percentage_error: 2.6389 - mean_squared_error: 3.2678e-04 - val_loss: 1.3592 - val_mean_absolute_error: 0.0065 - val_mean_absolute_percentage_error: 1.3592 - val_mean_squared_error: 7.2374e-05
# Epoch 8/30
# 693/693 [==============================] - 16s 23ms/step - loss: 2.6043 - mean_absolute_error: 0.0124 - mean_absolute_percentage_error: 2.6043 - mean_squared_error: 3.1770e-04 - val_loss: 1.2646 - val_mean_absolute_error: 0.0060 - val_mean_absolute_percentage_error: 1.2646 - val_mean_squared_error: 6.4086e-05
# Epoch 9/30
# 693/693 [==============================] - 16s 23ms/step - loss: 2.5943 - mean_absolute_error: 0.0123 - mean_absolute_percentage_error: 2.5943 - mean_squared_error: 3.0913e-04 - val_loss: 1.3493 - val_mean_absolute_error: 0.0060 - val_mean_absolute_percentage_error: 1.3493 - val_mean_squared_error: 6.3488e-05
# Epoch 10/30
# 693/693 [==============================] - 16s 23ms/step - loss: 2.4952 - mean_absolute_error: 0.0119 - mean_absolute_percentage_error: 2.4952 - mean_squared_error: 2.9163e-04 - val_loss: 1.4016 - val_mean_absolute_error: 0.0061 - val_mean_absolute_percentage_error: 1.4016 - val_mean_squared_error: 6.4249e-05
# Epoch 11/30
# 693/693 [==============================] - 16s 23ms/step - loss: 2.4980 - mean_absolute_error: 0.0119 - mean_absolute_percentage_error: 2.4980 - mean_squared_error: 2.9251e-04 - val_loss: 1.3453 - val_mean_absolute_error: 0.0063 - val_mean_absolute_percentage_error: 1.3453 - val_mean_squared_error: 6.3063e-05
# Epoch 12/30
# 693/693 [==============================] - 16s 23ms/step - loss: 2.4997 - mean_absolute_error: 0.0119 - mean_absolute_percentage_error: 2.4997 - mean_squared_error: 2.9030e-04 - val_loss: 1.8471 - val_mean_absolute_error: 0.0085 - val_mean_absolute_percentage_error: 1.8471 - val_mean_squared_error: 9.8017e-05
# Epoch 13/30
# 693/693 [==============================] - 16s 23ms/step - loss: 2.4744 - mean_absolute_error: 0.0117 - mean_absolute_percentage_error: 2.4744 - mean_squared_error: 2.8406e-04 - val_loss: 1.2116 - val_mean_absolute_error: 0.0052 - val_mean_absolute_percentage_error: 1.2116 - val_mean_squared_error: 4.8835e-05
# Epoch 14/30
# 693/693 [==============================] - 16s 23ms/step - loss: 2.4531 - mean_absolute_error: 0.0117 - mean_absolute_percentage_error: 2.4531 - mean_squared_error: 2.8680e-04 - val_loss: 1.0053 - val_mean_absolute_error: 0.0041 - val_mean_absolute_percentage_error: 1.0053 - val_mean_squared_error: 3.4385e-05
# Epoch 15/30
# 693/693 [==============================] - 16s 23ms/step - loss: 2.3952 - mean_absolute_error: 0.0114 - mean_absolute_percentage_error: 2.3952 - mean_squared_error: 2.7219e-04 - val_loss: 1.1053 - val_mean_absolute_error: 0.0050 - val_mean_absolute_percentage_error: 1.1053 - val_mean_squared_error: 4.3814e-05
# Epoch 16/30
# 693/693 [==============================] - 16s 23ms/step - loss: 2.4658 - mean_absolute_error: 0.0118 - mean_absolute_percentage_error: 2.4658 - mean_squared_error: 2.8427e-04 - val_loss: 1.2699 - val_mean_absolute_error: 0.0061 - val_mean_absolute_percentage_error: 1.2699 - val_mean_squared_error: 6.2651e-05
# Epoch 17/30
# 693/693 [==============================] - 16s 23ms/step - loss: 2.4008 - mean_absolute_error: 0.0114 - mean_absolute_percentage_error: 2.4008 - mean_squared_error: 2.7248e-04 - val_loss: 1.6250 - val_mean_absolute_error: 0.0082 - val_mean_absolute_percentage_error: 1.6250 - val_mean_squared_error: 1.1450e-04
# Epoch 18/30
# 693/693 [==============================] - 16s 23ms/step - loss: 2.3708 - mean_absolute_error: 0.0113 - mean_absolute_percentage_error: 2.3708 - mean_squared_error: 2.7350e-04 - val_loss: 1.3806 - val_mean_absolute_error: 0.0062 - val_mean_absolute_percentage_error: 1.3806 - val_mean_squared_error: 5.7326e-05
# Epoch 19/30
# 693/693 [==============================] - 16s 23ms/step - loss: 2.4110 - mean_absolute_error: 0.0115 - mean_absolute_percentage_error: 2.4110 - mean_squared_error: 2.7605e-04 - val_loss: 0.9471 - val_mean_absolute_error: 0.0042 - val_mean_absolute_percentage_error: 0.9471 - val_mean_squared_error: 3.5086e-05
# Epoch 20/30
# 693/693 [==============================] - 16s 23ms/step - loss: 2.3912 - mean_absolute_error: 0.0114 - mean_absolute_percentage_error: 2.3912 - mean_squared_error: 2.7250e-04 - val_loss: 1.7608 - val_mean_absolute_error: 0.0076 - val_mean_absolute_percentage_error: 1.7608 - val_mean_squared_error: 7.8251e-05
# Epoch 21/30
# 693/693 [==============================] - 16s 24ms/step - loss: 2.3547 - mean_absolute_error: 0.0112 - mean_absolute_percentage_error: 2.3547 - mean_squared_error: 2.6597e-04 - val_loss: 2.1378 - val_mean_absolute_error: 0.0106 - val_mean_absolute_percentage_error: 2.1378 - val_mean_squared_error: 1.8219e-04
# Epoch 22/30
# 693/693 [==============================] - 16s 23ms/step - loss: 2.4181 - mean_absolute_error: 0.0115 - mean_absolute_percentage_error: 2.4181 - mean_squared_error: 2.7724e-04 - val_loss: 2.2544 - val_mean_absolute_error: 0.0108 - val_mean_absolute_percentage_error: 2.2544 - val_mean_squared_error: 1.7992e-04
# Epoch 23/30
# 693/693 [==============================] - 16s 23ms/step - loss: 2.3479 - mean_absolute_error: 0.0112 - mean_absolute_percentage_error: 2.3479 - mean_squared_error: 2.6669e-04 - val_loss: 1.1861 - val_mean_absolute_error: 0.0048 - val_mean_absolute_percentage_error: 1.1861 - val_mean_squared_error: 4.1379e-05
# Epoch 24/30
# 693/693 [==============================] - 16s 23ms/step - loss: 2.3193 - mean_absolute_error: 0.0111 - mean_absolute_percentage_error: 2.3193 - mean_squared_error: 2.6101e-04 - val_loss: 1.1401 - val_mean_absolute_error: 0.0049 - val_mean_absolute_percentage_error: 1.1401 - val_mean_squared_error: 4.3037e-05
# Epoch 25/30
# 693/693 [==============================] - 16s 23ms/step - loss: 2.3447 - mean_absolute_error: 0.0112 - mean_absolute_percentage_error: 2.3447 - mean_squared_error: 2.6735e-04 - val_loss: 1.1046 - val_mean_absolute_error: 0.0046 - val_mean_absolute_percentage_error: 1.1046 - val_mean_squared_error: 3.8651e-05
# Epoch 26/30
# 693/693 [==============================] - 16s 23ms/step - loss: 2.3762 - mean_absolute_error: 0.0114 - mean_absolute_percentage_error: 2.3762 - mean_squared_error: 2.7179e-04 - val_loss: 1.1936 - val_mean_absolute_error: 0.0046 - val_mean_absolute_percentage_error: 1.1936 - val_mean_squared_error: 4.0923e-05
# Epoch 27/30
# 693/693 [==============================] - 16s 23ms/step - loss: 2.3238 - mean_absolute_error: 0.0111 - mean_absolute_percentage_error: 2.3238 - mean_squared_error: 2.6416e-04 - val_loss: 0.9806 - val_mean_absolute_error: 0.0044 - val_mean_absolute_percentage_error: 0.9806 - val_mean_squared_error: 3.7690e-05
# Epoch 28/30
# 693/693 [==============================] - 16s 23ms/step - loss: 2.3489 - mean_absolute_error: 0.0112 - mean_absolute_percentage_error: 2.3489 - mean_squared_error: 2.6249e-04 - val_loss: 1.8076 - val_mean_absolute_error: 0.0089 - val_mean_absolute_percentage_error: 1.8076 - val_mean_squared_error: 1.2771e-04
# Epoch 29/30
# 693/693 [==============================] - 16s 24ms/step - loss: 2.3345 - mean_absolute_error: 0.0112 - mean_absolute_percentage_error: 2.3345 - mean_squared_error: 2.6957e-04 - val_loss: 0.9410 - val_mean_absolute_error: 0.0042 - val_mean_absolute_percentage_error: 0.9410 - val_mean_squared_error: 3.4611e-05
# Epoch 30/30
# 693/693 [==============================] - 16s 24ms/step - loss: 2.3068 - mean_absolute_error: 0.0110 - mean_absolute_percentage_error: 2.3068 - mean_squared_error: 2.5787e-04 - val_loss: 1.1388 - val_mean_absolute_error: 0.0046 - val_mean_absolute_percentage_error: 1.1388 - val_mean_squared_error: 3.9785e-05
#
# ======== Model: lstm_2 ========
# description: {'units': [256, 256, 32], 'dropout': None, 'loss': 'mean_squared_error', 'batch_size': 128, 'epochs': 30, 'tic': 'ALL'}
#
# Epoch 1/30
# 693/693 [==============================] - 20s 24ms/step - loss: 0.0137 - mean_absolute_error: 0.0428 - mean_absolute_percentage_error: 9.4628 - mean_squared_error: 0.0137 - val_loss: 7.8396e-05 - val_mean_absolute_error: 0.0061 - val_mean_absolute_percentage_error: 1.4621 - val_mean_squared_error: 7.8396e-05
# Epoch 2/30
# 693/693 [==============================] - 16s 23ms/step - loss: 8.2719e-05 - mean_absolute_error: 0.0065 - mean_absolute_percentage_error: 1.5462 - mean_squared_error: 8.2719e-05 - val_loss: 5.7002e-05 - val_mean_absolute_error: 0.0051 - val_mean_absolute_percentage_error: 1.2124 - val_mean_squared_error: 5.7002e-05
# Epoch 3/30
# 693/693 [==============================] - 16s 23ms/step - loss: 7.2569e-05 - mean_absolute_error: 0.0061 - mean_absolute_percentage_error: 1.4334 - mean_squared_error: 7.2569e-05 - val_loss: 5.0263e-05 - val_mean_absolute_error: 0.0048 - val_mean_absolute_percentage_error: 1.1437 - val_mean_squared_error: 5.0263e-05
# Epoch 4/30
# 693/693 [==============================] - 16s 23ms/step - loss: 6.9323e-05 - mean_absolute_error: 0.0062 - mean_absolute_percentage_error: 1.4336 - mean_squared_error: 6.9323e-05 - val_loss: 4.5765e-05 - val_mean_absolute_error: 0.0045 - val_mean_absolute_percentage_error: 1.0885 - val_mean_squared_error: 4.5765e-05
# Epoch 5/30
# 693/693 [==============================] - 16s 23ms/step - loss: 6.5155e-05 - mean_absolute_error: 0.0060 - mean_absolute_percentage_error: 1.3853 - mean_squared_error: 6.5155e-05 - val_loss: 1.0685e-04 - val_mean_absolute_error: 0.0088 - val_mean_absolute_percentage_error: 2.0260 - val_mean_squared_error: 1.0685e-04
# Epoch 6/30
# 693/693 [==============================] - 16s 23ms/step - loss: 7.1424e-05 - mean_absolute_error: 0.0063 - mean_absolute_percentage_error: 1.4474 - mean_squared_error: 7.1424e-05 - val_loss: 4.1144e-05 - val_mean_absolute_error: 0.0044 - val_mean_absolute_percentage_error: 1.0364 - val_mean_squared_error: 4.1144e-05
# Epoch 7/30
# 693/693 [==============================] - 16s 23ms/step - loss: 6.6530e-05 - mean_absolute_error: 0.0061 - mean_absolute_percentage_error: 1.4033 - mean_squared_error: 6.6530e-05 - val_loss: 6.8832e-05 - val_mean_absolute_error: 0.0066 - val_mean_absolute_percentage_error: 1.4051 - val_mean_squared_error: 6.8832e-05
# Epoch 8/30
# 693/693 [==============================] - 16s 23ms/step - loss: 6.0379e-05 - mean_absolute_error: 0.0058 - mean_absolute_percentage_error: 1.3358 - mean_squared_error: 6.0379e-05 - val_loss: 1.3507e-04 - val_mean_absolute_error: 0.0104 - val_mean_absolute_percentage_error: 2.4153 - val_mean_squared_error: 1.3507e-04
# Epoch 9/30
# 693/693 [==============================] - 16s 23ms/step - loss: 7.1366e-05 - mean_absolute_error: 0.0064 - mean_absolute_percentage_error: 1.4643 - mean_squared_error: 7.1366e-05 - val_loss: 3.2961e-05 - val_mean_absolute_error: 0.0039 - val_mean_absolute_percentage_error: 0.9240 - val_mean_squared_error: 3.2961e-05
# Epoch 10/30
# 693/693 [==============================] - 16s 23ms/step - loss: 5.2023e-05 - mean_absolute_error: 0.0054 - mean_absolute_percentage_error: 1.2374 - mean_squared_error: 5.2023e-05 - val_loss: 3.3643e-05 - val_mean_absolute_error: 0.0040 - val_mean_absolute_percentage_error: 0.9330 - val_mean_squared_error: 3.3643e-05
# Epoch 11/30
# 693/693 [==============================] - 16s 23ms/step - loss: 5.1361e-05 - mean_absolute_error: 0.0054 - mean_absolute_percentage_error: 1.2395 - mean_squared_error: 5.1361e-05 - val_loss: 3.9045e-05 - val_mean_absolute_error: 0.0045 - val_mean_absolute_percentage_error: 1.1178 - val_mean_squared_error: 3.9045e-05
# Epoch 12/30
# 693/693 [==============================] - 16s 23ms/step - loss: 4.2148e-05 - mean_absolute_error: 0.0048 - mean_absolute_percentage_error: 1.1022 - mean_squared_error: 4.2148e-05 - val_loss: 1.1130e-04 - val_mean_absolute_error: 0.0090 - val_mean_absolute_percentage_error: 1.8732 - val_mean_squared_error: 1.1130e-04
# Epoch 13/30
# 693/693 [==============================] - 16s 23ms/step - loss: 4.7730e-05 - mean_absolute_error: 0.0052 - mean_absolute_percentage_error: 1.1887 - mean_squared_error: 4.7730e-05 - val_loss: 3.0252e-05 - val_mean_absolute_error: 0.0038 - val_mean_absolute_percentage_error: 0.8924 - val_mean_squared_error: 3.0252e-05
# Epoch 14/30
# 693/693 [==============================] - 16s 23ms/step - loss: 4.4262e-05 - mean_absolute_error: 0.0050 - mean_absolute_percentage_error: 1.1451 - mean_squared_error: 4.4262e-05 - val_loss: 8.2694e-05 - val_mean_absolute_error: 0.0078 - val_mean_absolute_percentage_error: 1.6900 - val_mean_squared_error: 8.2694e-05
# Epoch 15/30
# 693/693 [==============================] - 16s 23ms/step - loss: 4.1453e-05 - mean_absolute_error: 0.0048 - mean_absolute_percentage_error: 1.0926 - mean_squared_error: 4.1453e-05 - val_loss: 8.0420e-05 - val_mean_absolute_error: 0.0077 - val_mean_absolute_percentage_error: 1.7234 - val_mean_squared_error: 8.0420e-05
# Epoch 16/30
# 693/693 [==============================] - 16s 23ms/step - loss: 3.8703e-05 - mean_absolute_error: 0.0046 - mean_absolute_percentage_error: 1.0611 - mean_squared_error: 3.8703e-05 - val_loss: 4.7881e-05 - val_mean_absolute_error: 0.0054 - val_mean_absolute_percentage_error: 1.2116 - val_mean_squared_error: 4.7881e-05
# Epoch 17/30
# 693/693 [==============================] - 16s 23ms/step - loss: 3.4885e-05 - mean_absolute_error: 0.0043 - mean_absolute_percentage_error: 1.0089 - mean_squared_error: 3.4885e-05 - val_loss: 3.0519e-05 - val_mean_absolute_error: 0.0038 - val_mean_absolute_percentage_error: 0.8874 - val_mean_squared_error: 3.0519e-05
# Epoch 18/30
# 693/693 [==============================] - 16s 23ms/step - loss: 4.0859e-05 - mean_absolute_error: 0.0048 - mean_absolute_percentage_error: 1.1109 - mean_squared_error: 4.0859e-05 - val_loss: 2.6513e-05 - val_mean_absolute_error: 0.0034 - val_mean_absolute_percentage_error: 0.8057 - val_mean_squared_error: 2.6513e-05
# Epoch 19/30
# 693/693 [==============================] - 16s 23ms/step - loss: 3.5697e-05 - mean_absolute_error: 0.0044 - mean_absolute_percentage_error: 1.0255 - mean_squared_error: 3.5697e-05 - val_loss: 4.0470e-05 - val_mean_absolute_error: 0.0048 - val_mean_absolute_percentage_error: 1.1553 - val_mean_squared_error: 4.0470e-05
# Epoch 20/30
# 693/693 [==============================] - 16s 23ms/step - loss: 3.0929e-04 - mean_absolute_error: 0.0068 - mean_absolute_percentage_error: 1.5452 - mean_squared_error: 3.0929e-04 - val_loss: 3.6966e-05 - val_mean_absolute_error: 0.0042 - val_mean_absolute_percentage_error: 0.9974 - val_mean_squared_error: 3.6966e-05
# Epoch 21/30
# 693/693 [==============================] - 16s 23ms/step - loss: 3.1531e-05 - mean_absolute_error: 0.0039 - mean_absolute_percentage_error: 0.9419 - mean_squared_error: 3.1531e-05 - val_loss: 3.5038e-05 - val_mean_absolute_error: 0.0043 - val_mean_absolute_percentage_error: 1.0126 - val_mean_squared_error: 3.5038e-05
# Epoch 22/30
# 693/693 [==============================] - 16s 23ms/step - loss: 2.8966e-05 - mean_absolute_error: 0.0038 - mean_absolute_percentage_error: 0.9018 - mean_squared_error: 2.8966e-05 - val_loss: 2.6490e-05 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 0.8006 - val_mean_squared_error: 2.6490e-05
# Epoch 23/30
# 693/693 [==============================] - 16s 23ms/step - loss: 2.7872e-05 - mean_absolute_error: 0.0037 - mean_absolute_percentage_error: 0.8746 - mean_squared_error: 2.7872e-05 - val_loss: 2.6674e-05 - val_mean_absolute_error: 0.0034 - val_mean_absolute_percentage_error: 0.8188 - val_mean_squared_error: 2.6674e-05
# Epoch 24/30
# 693/693 [==============================] - 16s 23ms/step - loss: 3.0061e-05 - mean_absolute_error: 0.0039 - mean_absolute_percentage_error: 0.9224 - mean_squared_error: 3.0061e-05 - val_loss: 2.5500e-05 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 0.7835 - val_mean_squared_error: 2.5500e-05
# Epoch 25/30
# 693/693 [==============================] - 16s 23ms/step - loss: 3.3198e-05 - mean_absolute_error: 0.0042 - mean_absolute_percentage_error: 0.9767 - mean_squared_error: 3.3198e-05 - val_loss: 2.9495e-05 - val_mean_absolute_error: 0.0038 - val_mean_absolute_percentage_error: 0.8831 - val_mean_squared_error: 2.9495e-05
# Epoch 26/30
# 693/693 [==============================] - 16s 23ms/step - loss: 3.5800e-05 - mean_absolute_error: 0.0044 - mean_absolute_percentage_error: 1.0215 - mean_squared_error: 3.5800e-05 - val_loss: 2.5589e-05 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 0.7866 - val_mean_squared_error: 2.5589e-05
# Epoch 27/30
# 693/693 [==============================] - 16s 24ms/step - loss: 3.2949e-05 - mean_absolute_error: 0.0042 - mean_absolute_percentage_error: 0.9714 - mean_squared_error: 3.2949e-05 - val_loss: 3.4187e-05 - val_mean_absolute_error: 0.0043 - val_mean_absolute_percentage_error: 0.9962 - val_mean_squared_error: 3.4187e-05
# Epoch 28/30
# 693/693 [==============================] - 16s 23ms/step - loss: 3.4696e-05 - mean_absolute_error: 0.0043 - mean_absolute_percentage_error: 1.0010 - mean_squared_error: 3.4696e-05 - val_loss: 8.7009e-05 - val_mean_absolute_error: 0.0081 - val_mean_absolute_percentage_error: 1.7172 - val_mean_squared_error: 8.7009e-05
# Epoch 29/30
# 693/693 [==============================] - 17s 24ms/step - loss: 3.1492e-05 - mean_absolute_error: 0.0041 - mean_absolute_percentage_error: 0.9514 - mean_squared_error: 3.1492e-05 - val_loss: 4.4745e-05 - val_mean_absolute_error: 0.0052 - val_mean_absolute_percentage_error: 1.1798 - val_mean_squared_error: 4.4745e-05
# Epoch 30/30
# 693/693 [==============================] - 16s 23ms/step - loss: 3.4412e-05 - mean_absolute_error: 0.0043 - mean_absolute_percentage_error: 1.0018 - mean_squared_error: 3.4412e-05 - val_loss: 3.2975e-05 - val_mean_absolute_error: 0.0041 - val_mean_absolute_percentage_error: 0.9677 - val_mean_squared_error: 3.2975e-05
#
# ======== Model: lstm_3 ========
# description: {'units': [256, 256, 32], 'dropout': None, 'loss': 'mean_squared_logarithmic_error', 'batch_size': 128, 'epochs': 30, 'tic': 'ALL'}
#
# Epoch 1/30
# 693/693 [==============================] - 20s 24ms/step - loss: 0.1560 - mean_absolute_error: 2.4962 - mean_absolute_percentage_error: 547.5994 - mean_squared_error: 6.9892 - val_loss: 0.1563 - val_mean_absolute_error: 2.8347 - val_mean_absolute_percentage_error: 623.0977 - val_mean_squared_error: 8.2133
# Epoch 2/30
# 693/693 [==============================] - 15s 22ms/step - loss: 0.1568 - mean_absolute_error: 2.8356 - mean_absolute_percentage_error: 622.7232 - mean_squared_error: 8.2223 - val_loss: 0.1563 - val_mean_absolute_error: 2.8347 - val_mean_absolute_percentage_error: 623.0977 - val_mean_squared_error: 8.2133_absol
# Epoch 3/30
# 693/693 [==============================] - 15s 22ms/step - loss: 0.1571 - mean_absolute_error: 2.8376 - mean_absolute_percentage_error: 622.5365 - mean_squared_error: 8.2336 - val_loss: 0.1563 - val_mean_absolute_error: 2.8347 - val_mean_absolute_percentage_error: 623.0977 - val_mean_squared_error: 8.2133: 0.1571 - mean_absolute_error: 2.8377 - mean_absolute_percentage_error: 622.5324 - mean
# Epoch 4/30
# 693/693 [==============================] - 15s 22ms/step - loss: 0.1563 - mean_absolute_error: 2.8330 - mean_absolute_percentage_error: 623.6697 - mean_squared_error: 8.2071 - val_loss: 0.1563 - val_mean_absolute_error: 2.8347 - val_mean_absolute_percentage_error: 623.0977 - val_mean_squared_error: 8.2133
# Epoch 5/30
# 693/693 [==============================] - 15s 22ms/step - loss: 0.1577 - mean_absolute_error: 2.8405 - mean_absolute_percentage_error: 621.7967 - mean_squared_error: 8.2507 - val_loss: 0.1563 - val_mean_absolute_error: 2.8347 - val_mean_absolute_percentage_error: 623.0977 - val_mean_squared_error: 8.2133
# Epoch 6/30
# 693/693 [==============================] - 15s 22ms/step - loss: 0.1573 - mean_absolute_error: 2.8385 - mean_absolute_percentage_error: 622.4605 - mean_squared_error: 8.2390 - val_loss: 0.1563 - val_mean_absolute_error: 2.8347 - val_mean_absolute_percentage_error: 623.0977 - val_mean_squared_error: 8.2133
# Epoch 7/30
# 693/693 [==============================] - 15s 22ms/step - loss: 0.1576 - mean_absolute_error: 2.8397 - mean_absolute_percentage_error: 622.0066 - mean_squared_error: 8.2464 - val_loss: 0.1563 - val_mean_absolute_error: 2.8347 - val_mean_absolute_percentage_error: 623.0977 - val_mean_squared_error: 8.2133
# Epoch 8/30
# 693/693 [==============================] - 15s 22ms/step - loss: 0.1571 - mean_absolute_error: 2.8374 - mean_absolute_percentage_error: 622.3307 - mean_squared_error: 8.2320 - val_loss: 0.1563 - val_mean_absolute_error: 2.8347 - val_mean_absolute_percentage_error: 623.0977 - val_mean_squared_error: 8.2133
# Epoch 9/30
# 693/693 [==============================] - 15s 22ms/step - loss: 0.1571 - mean_absolute_error: 2.8375 - mean_absolute_percentage_error: 622.7492 - mean_squared_error: 8.2328 - val_loss: 0.1563 - val_mean_absolute_error: 2.8347 - val_mean_absolute_percentage_error: 623.0977 - val_mean_squared_error: 8.2133are
# Epoch 10/30
# 693/693 [==============================] - 15s 22ms/step - loss: 0.1573 - mean_absolute_error: 2.8378 - mean_absolute_percentage_error: 622.4061 - mean_squared_error: 8.2356 - val_loss: 0.1563 - val_mean_absolute_error: 2.8347 - val_mean_absolute_percentage_error: 623.0977 - val_mean_squared_error: 8.2133576 - mean_absolute_error: 2.8387 - - ETA: 2s - loss: 0.1573 - mean_absolute_error: 2.8380 - mean_absolute_percent
# Epoch 11/30
# 693/693 [==============================] - 15s 22ms/step - loss: 0.1569 - mean_absolute_error: 2.8360 - mean_absolute_percentage_error: 622.7886 - mean_squared_error: 8.2240 - val_loss: 0.1563 - val_mean_absolute_error: 2.8347 - val_mean_absolute_percentage_error: 623.0977 - val_mean_squared_error: 8.2133
# Epoch 12/30
# 693/693 [==============================] - 15s 22ms/step - loss: 0.1570 - mean_absolute_error: 2.8369 - mean_absolute_percentage_error: 622.5545 - mean_squared_error: 8.2289 - val_loss: 0.1563 - val_mean_absolute_error: 2.8347 - val_mean_absolute_percentage_error: 623.0977 - val_mean_squared_error: 8.2133
# Epoch 13/30
# 693/693 [==============================] - 15s 22ms/step - loss: 0.1571 - mean_absolute_error: 2.8373 - mean_absolute_percentage_error: 622.5866 - mean_squared_error: 8.2315 - val_loss: 0.1563 - val_mean_absolute_error: 2.8347 - val_mean_absolute_percentage_error: 623.0977 - val_mean_squared_error: 8.2133
# Epoch 14/30
# 693/693 [==============================] - 16s 23ms/step - loss: 0.1568 - mean_absolute_error: 2.8360 - mean_absolute_percentage_error: 622.8095 - mean_squared_error: 8.2242 - val_loss: 0.1563 - val_mean_absolute_error: 2.8347 - val_mean_absolute_percentage_error: 623.0977 - val_mean_squared_error: 8.2133
# Epoch 15/30
# 693/693 [==============================] - 16s 23ms/step - loss: 0.1566 - mean_absolute_error: 2.8344 - mean_absolute_percentage_error: 623.0696 - mean_squared_error: 8.2149 - val_loss: 0.1563 - val_mean_absolute_error: 2.8347 - val_mean_absolute_percentage_error: 623.0977 - val_mean_squared_error: 8.2133
# Epoch 16/30
# 693/693 [==============================] - 16s 23ms/step - loss: 0.1571 - mean_absolute_error: 2.8381 - mean_absolute_percentage_error: 622.6254 - mean_squared_error: 8.2370 - val_loss: 0.1563 - val_mean_absolute_error: 2.8347 - val_mean_absolute_percentage_error: 623.0977 - val_mean_squared_error: 8.2133
# Epoch 17/30
# 693/693 [==============================] - 16s 24ms/step - loss: 0.1573 - mean_absolute_error: 2.8387 - mean_absolute_percentage_error: 622.4853 - mean_squared_error: 8.2402 - val_loss: 0.1563 - val_mean_absolute_error: 2.8347 - val_mean_absolute_percentage_error: 623.0977 - val_mean_squared_error: 8.2133
# Epoch 18/30
# 693/693 [==============================] - 16s 24ms/step - loss: 0.1565 - mean_absolute_error: 2.8340 - mean_absolute_percentage_error: 623.3873 - mean_squared_error: 8.2129 - val_loss: 0.1563 - val_mean_absolute_error: 2.8347 - val_mean_absolute_percentage_error: 623.0977 - val_mean_squared_error: 8.2133
# Epoch 19/30
# 693/693 [==============================] - 16s 24ms/step - loss: 0.1571 - mean_absolute_error: 2.8377 - mean_absolute_percentage_error: 622.4804 - mean_squared_error: 8.2338 - val_loss: 0.1563 - val_mean_absolute_error: 2.8347 - val_mean_absolute_percentage_error: 623.0977 - val_mean_squared_error: 8.2133
# Epoch 20/30
# 693/693 [==============================] - 16s 24ms/step - loss: 0.1568 - mean_absolute_error: 2.8363 - mean_absolute_percentage_error: 622.8214 - mean_squared_error: 8.2255 - val_loss: 0.1563 - val_mean_absolute_error: 2.8347 - val_mean_absolute_percentage_error: 623.0977 - val_mean_squared_error: 8.2133
# Epoch 21/30
# 693/693 [==============================] - 16s 24ms/step - loss: 0.1572 - mean_absolute_error: 2.8382 - mean_absolute_percentage_error: 622.4363 - mean_squared_error: 8.2370 - val_loss: 0.1563 - val_mean_absolute_error: 2.8347 - val_mean_absolute_percentage_error: 623.0977 - val_mean_squared_error: 8.2133
# Epoch 22/30
# 693/693 [==============================] - 16s 23ms/step - loss: 0.1569 - mean_absolute_error: 2.8360 - mean_absolute_percentage_error: 622.7743 - mean_squared_error: 8.2237 - val_loss: 0.1563 - val_mean_absolute_error: 2.8347 - val_mean_absolute_percentage_error: 623.0977 - val_mean_squared_error: 8.2133
# Epoch 23/30
# 693/693 [==============================] - 16s 23ms/step - loss: 0.1570 - mean_absolute_error: 2.8371 - mean_absolute_percentage_error: 622.8198 - mean_squared_error: 8.2305 - val_loss: 0.1563 - val_mean_absolute_error: 2.8347 - val_mean_absolute_percentage_error: 623.0977 - val_mean_squared_error: 8.2133
# Epoch 24/30
# 693/693 [==============================] - 16s 23ms/step - loss: 0.1568 - mean_absolute_error: 2.8357 - mean_absolute_percentage_error: 622.7474 - mean_squared_error: 8.2228 - val_loss: 0.1563 - val_mean_absolute_error: 2.8347 - val_mean_absolute_percentage_error: 623.0977 - val_mean_squared_error: 8.2133
# Epoch 25/30
# 693/693 [==============================] - 16s 24ms/step - loss: 0.1571 - mean_absolute_error: 2.8372 - mean_absolute_percentage_error: 622.6865 - mean_squared_error: 8.2315 - val_loss: 0.1563 - val_mean_absolute_error: 2.8347 - val_mean_absolute_percentage_error: 623.0977 - val_mean_squared_error: 8.2133
# Epoch 26/30
# 693/693 [==============================] - 17s 24ms/step - loss: 0.1566 - mean_absolute_error: 2.8348 - mean_absolute_percentage_error: 623.2122 - mean_squared_error: 8.2159 - val_loss: 0.1563 - val_mean_absolute_error: 2.8347 - val_mean_absolute_percentage_error: 623.0977 - val_mean_squared_error: 8.2133
# Epoch 27/30
# 693/693 [==============================] - 17s 24ms/step - loss: 0.1574 - mean_absolute_error: 2.8396 - mean_absolute_percentage_error: 622.0976 - mean_squared_error: 8.2446 - val_loss: 0.1563 - val_mean_absolute_error: 2.8347 - val_mean_absolute_percentage_error: 623.0977 - val_mean_squared_error: 8.2133
# Epoch 28/30
# 693/693 [==============================] - 16s 24ms/step - loss: 0.1572 - mean_absolute_error: 2.8382 - mean_absolute_percentage_error: 622.1980 - mean_squared_error: 8.2360 - val_loss: 0.1563 - val_mean_absolute_error: 2.8347 - val_mean_absolute_percentage_error: 623.0977 - val_mean_squared_error: 8.2133
# Epoch 29/30
# 693/693 [==============================] - 16s 23ms/step - loss: 0.1572 - mean_absolute_error: 2.8381 - mean_absolute_percentage_error: 622.5301 - mean_squared_error: 8.2357 - val_loss: 0.1563 - val_mean_absolute_error: 2.8347 - val_mean_absolute_percentage_error: 623.0977 - val_mean_squared_error: 8.2133
# Epoch 30/30
# 693/693 [==============================] - 16s 23ms/step - loss: 0.1566 - mean_absolute_error: 2.8345 - mean_absolute_percentage_error: 623.1504 - mean_squared_error: 8.2147 - val_loss: 0.1563 - val_mean_absolute_error: 2.8347 - val_mean_absolute_percentage_error: 623.0977 - val_mean_squared_error: 8.2133
#
# ======== Model: lstm_4 ========
# description: {'units': [256, 256, 32], 'dropout': None, 'loss': 'huber_loss', 'batch_size': 128, 'epochs': 30, 'tic': 'ALL'}
#
# Epoch 1/30
# 693/693 [==============================] - 19s 23ms/step - loss: 0.0080 - mean_absolute_error: 0.0453 - mean_absolute_percentage_error: 10.0340 - mean_squared_error: 0.0160 - val_loss: 4.3992e-05 - val_mean_absolute_error: 0.0064 - val_mean_absolute_percentage_error: 1.5143 - val_mean_squared_error: 8.7984e-05
# Epoch 2/30
# 693/693 [==============================] - 15s 22ms/step - loss: 4.2775e-05 - mean_absolute_error: 0.0066 - mean_absolute_percentage_error: 1.5651 - mean_squared_error: 8.5549e-05 - val_loss: 4.1006e-05 - val_mean_absolute_error: 0.0065 - val_mean_absolute_percentage_error: 1.5847 - val_mean_squared_error: 8.2013e-05
# Epoch 3/30
# 693/693 [==============================] - 16s 23ms/step - loss: 3.6489e-05 - mean_absolute_error: 0.0062 - mean_absolute_percentage_error: 1.4538 - mean_squared_error: 7.2978e-05 - val_loss: 2.7634e-05 - val_mean_absolute_error: 0.0050 - val_mean_absolute_percentage_error: 1.1871 - val_mean_squared_error: 5.5268e-05
# Epoch 4/30
# 693/693 [==============================] - 16s 23ms/step - loss: 3.6840e-05 - mean_absolute_error: 0.0063 - mean_absolute_percentage_error: 1.4615 - mean_squared_error: 7.3680e-05 - val_loss: 1.0669e-04 - val_mean_absolute_error: 0.0127 - val_mean_absolute_percentage_error: 2.7221 - val_mean_squared_error: 2.1338e-04
# Epoch 5/30
# 693/693 [==============================] - 15s 22ms/step - loss: 3.9678e-05 - mean_absolute_error: 0.0066 - mean_absolute_percentage_error: 1.5138 - mean_squared_error: 7.9356e-05 - val_loss: 2.2493e-05 - val_mean_absolute_error: 0.0044 - val_mean_absolute_percentage_error: 1.0488 - val_mean_squared_error: 4.4986e-05
# Epoch 6/30
# 693/693 [==============================] - 15s 22ms/step - loss: 3.1598e-05 - mean_absolute_error: 0.0059 - mean_absolute_percentage_error: 1.3655 - mean_squared_error: 6.3196e-05 - val_loss: 8.0682e-05 - val_mean_absolute_error: 0.0113 - val_mean_absolute_percentage_error: 2.4905 - val_mean_squared_error: 1.6136e-04
# Epoch 7/30
# 693/693 [==============================] - 15s 21ms/step - loss: 3.4027e-05 - mean_absolute_error: 0.0062 - mean_absolute_percentage_error: 1.4184 - mean_squared_error: 6.8053e-05 - val_loss: 2.0121e-05 - val_mean_absolute_error: 0.0042 - val_mean_absolute_percentage_error: 1.0092 - val_mean_squared_error: 4.0242e-05
# Epoch 8/30
# 693/693 [==============================] - 15s 22ms/step - loss: 2.8641e-05 - mean_absolute_error: 0.0056 - mean_absolute_percentage_error: 1.3008 - mean_squared_error: 5.7282e-05 - val_loss: 2.7915e-05 - val_mean_absolute_error: 0.0057 - val_mean_absolute_percentage_error: 1.2948 - val_mean_squared_error: 5.5829e-05
# Epoch 9/30
# 693/693 [==============================] - 15s 22ms/step - loss: 3.2766e-05 - mean_absolute_error: 0.0061 - mean_absolute_percentage_error: 1.3934 - mean_squared_error: 6.5531e-05 - val_loss: 8.2523e-05 - val_mean_absolute_error: 0.0114 - val_mean_absolute_percentage_error: 2.4269 - val_mean_squared_error: 1.6505e-04
# Epoch 10/30
# 693/693 [==============================] - 15s 22ms/step - loss: 2.6427e-05 - mean_absolute_error: 0.0055 - mean_absolute_percentage_error: 1.2538 - mean_squared_error: 5.2854e-05 - val_loss: 3.5426e-05 - val_mean_absolute_error: 0.0069 - val_mean_absolute_percentage_error: 1.6042 - val_mean_squared_error: 7.0853e-05
# Epoch 11/30
# 693/693 [==============================] - 15s 22ms/step - loss: 3.0727e-05 - mean_absolute_error: 0.0058 - mean_absolute_percentage_error: 1.3189 - mean_squared_error: 6.1455e-05 - val_loss: 3.5040e-05 - val_mean_absolute_error: 0.0070 - val_mean_absolute_percentage_error: 1.6202 - val_mean_squared_error: 7.0081e-05
# Epoch 12/30
# 693/693 [==============================] - 15s 22ms/step - loss: 2.4768e-05 - mean_absolute_error: 0.0053 - mean_absolute_percentage_error: 1.2058 - mean_squared_error: 4.9536e-05 - val_loss: 2.2338e-05 - val_mean_absolute_error: 0.0051 - val_mean_absolute_percentage_error: 1.2294 - val_mean_squared_error: 4.4675e-05
# Epoch 13/30
# 693/693 [==============================] - 15s 22ms/step - loss: 2.3680e-05 - mean_absolute_error: 0.0050 - mean_absolute_percentage_error: 1.1657 - mean_squared_error: 4.7360e-05 - val_loss: 1.6484e-05 - val_mean_absolute_error: 0.0040 - val_mean_absolute_percentage_error: 0.9392 - val_mean_squared_error: 3.2969e-05
# Epoch 14/30
# 693/693 [==============================] - 15s 22ms/step - loss: 2.0882e-05 - mean_absolute_error: 0.0048 - mean_absolute_percentage_error: 1.1151 - mean_squared_error: 4.1765e-05 - val_loss: 1.4383e-05 - val_mean_absolute_error: 0.0035 - val_mean_absolute_percentage_error: 0.8334 - val_mean_squared_error: 2.8765e-05
# Epoch 15/30
# 693/693 [==============================] - 15s 22ms/step - loss: 1.9155e-05 - mean_absolute_error: 0.0046 - mean_absolute_percentage_error: 1.0658 - mean_squared_error: 3.8311e-05 - val_loss: 2.1082e-05 - val_mean_absolute_error: 0.0049 - val_mean_absolute_percentage_error: 1.1484 - val_mean_squared_error: 4.2164e-05 mean_absolute_error: 0.0046 - mean_absolute_percentag
# Epoch 16/30
# 693/693 [==============================] - 15s 22ms/step - loss: 2.1959e-05 - mean_absolute_error: 0.0050 - mean_absolute_percentage_error: 1.1499 - mean_squared_error: 4.3919e-05 - val_loss: 4.4795e-05 - val_mean_absolute_error: 0.0083 - val_mean_absolute_percentage_error: 1.9019 - val_mean_squared_error: 8.9590e-05
# Epoch 17/30
# 693/693 [==============================] - 15s 22ms/step - loss: 2.0594e-05 - mean_absolute_error: 0.0048 - mean_absolute_percentage_error: 1.1013 - mean_squared_error: 4.1187e-05 - val_loss: 1.4464e-05 - val_mean_absolute_error: 0.0036 - val_mean_absolute_percentage_error: 0.8523 - val_mean_squared_error: 2.8928e-05046e-05 - mean_absolute_error: 0.0050 - mean_absolute_percentage_error: 1.1435 - mean_squared_error: 4.4 - ETA: 5s - loss: 2.1880e-05 - mean_absolute_error: 0.0050 - mean_absolute_percentage_error: 1.1 - ETA: 3s - loss: 2.1210e-05 - mean_absolute_error: 0.0049 - mean_absolute_per
# Epoch 18/30
# 693/693 [==============================] - 15s 22ms/step - loss: 1.7930e-05 - mean_absolute_error: 0.0044 - mean_absolute_percentage_error: 1.0205 - mean_squared_error: 3.5860e-05 - val_loss: 1.6946e-05 - val_mean_absolute_error: 0.0042 - val_mean_absolute_percentage_error: 0.9459 - val_mean_squared_error: 3.3891e-05
# Epoch 19/30
# 693/693 [==============================] - 15s 22ms/step - loss: 1.8012e-05 - mean_absolute_error: 0.0044 - mean_absolute_percentage_error: 1.0188 - mean_squared_error: 3.6024e-05 - val_loss: 1.3682e-05 - val_mean_absolute_error: 0.0034 - val_mean_absolute_percentage_error: 0.8261 - val_mean_squared_error: 2.7364e-05
# Epoch 20/30
# 693/693 [==============================] - 15s 22ms/step - loss: 1.7373e-05 - mean_absolute_error: 0.0043 - mean_absolute_percentage_error: 1.0009 - mean_squared_error: 3.4747e-05 - val_loss: 2.3224e-05 - val_mean_absolute_error: 0.0054 - val_mean_absolute_percentage_error: 1.2390 - val_mean_squared_error: 4.6447e-05
# Epoch 21/30
# 693/693 [==============================] - 15s 22ms/step - loss: 1.7000e-05 - mean_absolute_error: 0.0043 - mean_absolute_percentage_error: 1.0000 - mean_squared_error: 3.4000e-05 - val_loss: 2.0549e-05 - val_mean_absolute_error: 0.0050 - val_mean_absolute_percentage_error: 1.1090 - val_mean_squared_error: 4.1099e-05
# Epoch 22/30
# 693/693 [==============================] - 15s 22ms/step - loss: 1.8659e-05 - mean_absolute_error: 0.0045 - mean_absolute_percentage_error: 1.0468 - mean_squared_error: 3.7318e-05 - val_loss: 1.4500e-05 - val_mean_absolute_error: 0.0037 - val_mean_absolute_percentage_error: 0.8726 - val_mean_squared_error: 2.8999e-05
# Epoch 23/30
# 693/693 [==============================] - 15s 22ms/step - loss: 1.6477e-05 - mean_absolute_error: 0.0042 - mean_absolute_percentage_error: 0.9789 - mean_squared_error: 3.2955e-05 - val_loss: 3.0142e-05 - val_mean_absolute_error: 0.0064 - val_mean_absolute_percentage_error: 1.4296 - val_mean_squared_error: 6.0284e-05
# Epoch 24/30
# ...
# Epoch 6/30
# 2771/2771 [==============================] - 57s 21ms/step - loss: 1.1470 - mean_absolute_error: 0.0050 - mean_absolute_percentage_error: 1.1470 - mean_squared_error: 4.5308e-05 - val_loss: 1.9675 - val_mean_absolute_error: 0.0091 - val_mean_absolute_percentage_error: 1.9675 - val_mean_squared_error: 1.0471e-04
# Epoch 7/30
# 2771/2771 [==============================] - 56s 20ms/step - loss: 1.1163 - mean_absolute_error: 0.0049 - mean_absolute_percentage_error: 1.1163 - mean_squared_error: 4.3525e-05 - val_loss: 0.8771 - val_mean_absolute_error: 0.0036 - val_mean_absolute_percentage_error: 0.8771 - val_mean_squared_error: 2.6267e-05
# Epoch 8/30
# 2771/2771 [==============================] - 56s 20ms/step - loss: 1.0673 - mean_absolute_error: 0.0046 - mean_absolute_percentage_error: 1.0673 - mean_squared_error: 3.9517e-05 - val_loss: 0.8170 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 0.8170 - val_mean_squared_error: 2.3423e-05
# Epoch 9/30
# 2771/2771 [==============================] - 56s 20ms/step - loss: 1.0615 - mean_absolute_error: 0.0046 - mean_absolute_percentage_error: 1.0615 - mean_squared_error: 3.9183e-05 - val_loss: 0.8450 - val_mean_absolute_error: 0.0036 - val_mean_absolute_percentage_error: 0.8450 - val_mean_squared_error: 2.5116e-05
# Epoch 10/30
# 2771/2771 [==============================] - 53s 19ms/step - loss: 1.0296 - mean_absolute_error: 0.0045 - mean_absolute_percentage_error: 1.0296 - mean_squared_error: 3.7904e-05 - val_loss: 0.8242 - val_mean_absolute_error: 0.0034 - val_mean_absolute_percentage_error: 0.8242 - val_mean_squared_error: 2.4382e-05
# Epoch 11/30
# 2771/2771 [==============================] - 62s 22ms/step - loss: 1.0009 - mean_absolute_error: 0.0043 - mean_absolute_percentage_error: 1.0009 - mean_squared_error: 3.6276e-05 - val_loss: 0.9132 - val_mean_absolute_error: 0.0040 - val_mean_absolute_percentage_error: 0.9132 - val_mean_squared_error: 2.9660e-05
# Epoch 12/30
# 2771/2771 [==============================] - 71s 26ms/step - loss: 0.9912 - mean_absolute_error: 0.0043 - mean_absolute_percentage_error: 0.9912 - mean_squared_error: 3.5060e-05 - val_loss: 1.5037 - val_mean_absolute_error: 0.0073 - val_mean_absolute_percentage_error: 1.5037 - val_mean_squared_error: 7.9566e-05
# Epoch 13/30
# 2771/2771 [==============================] - 65s 24ms/step - loss: 0.9792 - mean_absolute_error: 0.0042 - mean_absolute_percentage_error: 0.9792 - mean_squared_error: 3.4067e-05 - val_loss: 0.9540 - val_mean_absolute_error: 0.0040 - val_mean_absolute_percentage_error: 0.9540 - val_mean_squared_error: 2.9829e-05
# Epoch 14/30
# 2771/2771 [==============================] - 65s 23ms/step - loss: 0.9470 - mean_absolute_error: 0.0041 - mean_absolute_percentage_error: 0.9470 - mean_squared_error: 3.2355e-05 - val_loss: 1.4157 - val_mean_absolute_error: 0.0064 - val_mean_absolute_percentage_error: 1.4157 - val_mean_squared_error: 5.6922e-05
# Epoch 15/30
# 2771/2771 [==============================] - 62s 22ms/step - loss: 0.9862 - mean_absolute_error: 0.0043 - mean_absolute_percentage_error: 0.9862 - mean_squared_error: 3.4520e-05 - val_loss: 1.0185 - val_mean_absolute_error: 0.0044 - val_mean_absolute_percentage_error: 1.0185 - val_mean_squared_error: 3.2191e-05
# Epoch 16/30
# 2771/2771 [==============================] - 55s 20ms/step - loss: 0.9614 - mean_absolute_error: 0.0041 - mean_absolute_percentage_error: 0.9614 - mean_squared_error: 3.2543e-05 - val_loss: 1.4350 - val_mean_absolute_error: 0.0064 - val_mean_absolute_percentage_error: 1.4350 - val_mean_squared_error: 5.6098e-05
# Epoch 17/30
# 2771/2771 [==============================] - 53s 19ms/step - loss: 0.9830 - mean_absolute_error: 0.0042 - mean_absolute_percentage_error: 0.9830 - mean_squared_error: 3.4083e-05 - val_loss: 0.7572 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 0.7572 - val_mean_squared_error: 2.1747e-05
# Epoch 18/30
# 2771/2771 [==============================] - 56s 20ms/step - loss: 0.9346 - mean_absolute_error: 0.0040 - mean_absolute_percentage_error: 0.9346 - mean_squared_error: 3.1677e-05 - val_loss: 1.1398 - val_mean_absolute_error: 0.0049 - val_mean_absolute_percentage_error: 1.1398 - val_mean_squared_error: 3.7805e-05
# Epoch 19/30
# 2771/2771 [==============================] - 54s 19ms/step - loss: 0.9231 - mean_absolute_error: 0.0040 - mean_absolute_percentage_error: 0.9231 - mean_squared_error: 3.0875e-05 - val_loss: 0.8253 - val_mean_absolute_error: 0.0035 - val_mean_absolute_percentage_error: 0.8253 - val_mean_squared_error: 2.4581e-05
# Epoch 20/30
# 2771/2771 [==============================] - 55s 20ms/step - loss: 0.9487 - mean_absolute_error: 0.0041 - mean_absolute_percentage_error: 0.9487 - mean_squared_error: 3.2537e-05 - val_loss: 0.9478 - val_mean_absolute_error: 0.0039 - val_mean_absolute_percentage_error: 0.9478 - val_mean_squared_error: 2.8643e-05
# Epoch 21/30
# 2771/2771 [==============================] - 53s 19ms/step - loss: 0.9337 - mean_absolute_error: 0.0040 - mean_absolute_percentage_error: 0.9337 - mean_squared_error: 3.1310e-05 - val_loss: 0.7935 - val_mean_absolute_error: 0.0032 - val_mean_absolute_percentage_error: 0.7935 - val_mean_squared_error: 2.2883e-05
# Epoch 22/30
# 2771/2771 [==============================] - 56s 20ms/step - loss: 0.9249 - mean_absolute_error: 0.0040 - mean_absolute_percentage_error: 0.9249 - mean_squared_error: 3.0715e-05 - val_loss: 0.9930 - val_mean_absolute_error: 0.0046 - val_mean_absolute_percentage_error: 0.9930 - val_mean_squared_error: 3.5426e-05
# Epoch 23/30
# 2771/2771 [==============================] - 53s 19ms/step - loss: 0.9182 - mean_absolute_error: 0.0039 - mean_absolute_percentage_error: 0.9182 - mean_squared_error: 3.0090e-05 - val_loss: 0.8253 - val_mean_absolute_error: 0.0036 - val_mean_absolute_percentage_error: 0.8253 - val_mean_squared_error: 2.5518e-05
# Epoch 24/30
# 2771/2771 [==============================] - 53s 19ms/step - loss: 0.9059 - mean_absolute_error: 0.0039 - mean_absolute_percentage_error: 0.9059 - mean_squared_error: 2.9765e-05 - val_loss: 0.7644 - val_mean_absolute_error: 0.0032 - val_mean_absolute_percentage_error: 0.7644 - val_mean_squared_error: 2.2036e-05
# Epoch 25/30
# 2771/2771 [==============================] - 54s 19ms/step - loss: 0.9116 - mean_absolute_error: 0.0039 - mean_absolute_percentage_error: 0.9116 - mean_squared_error: 3.0242e-05 - val_loss: 0.8268 - val_mean_absolute_error: 0.0035 - val_mean_absolute_percentage_error: 0.8268 - val_mean_squared_error: 2.4809e-05
# Epoch 26/30
# 2771/2771 [==============================] - 53s 19ms/step - loss: 0.8960 - mean_absolute_error: 0.0038 - mean_absolute_percentage_error: 0.8960 - mean_squared_error: 2.9628e-05 - val_loss: 1.0693 - val_mean_absolute_error: 0.0045 - val_mean_absolute_percentage_error: 1.0693 - val_mean_squared_error: 3.3616e-05
# Epoch 27/30
# 2771/2771 [==============================] - 54s 19ms/step - loss: 0.9184 - mean_absolute_error: 0.0039 - mean_absolute_percentage_error: 0.9184 - mean_squared_error: 3.0324e-05 - val_loss: 0.9193 - val_mean_absolute_error: 0.0041 - val_mean_absolute_percentage_error: 0.9193 - val_mean_squared_error: 3.0027e-05
# Epoch 28/30
# 2771/2771 [==============================] - 65s 24ms/step - loss: 0.9158 - mean_absolute_error: 0.0039 - mean_absolute_percentage_error: 0.9158 - mean_squared_error: 3.0286e-05 - val_loss: 0.8928 - val_mean_absolute_error: 0.0037 - val_mean_absolute_percentage_error: 0.8928 - val_mean_squared_error: 2.6251e-05
# Epoch 29/30
# 2771/2771 [==============================] - 67s 24ms/step - loss: 0.9089 - mean_absolute_error: 0.0039 - mean_absolute_percentage_error: 0.9089 - mean_squared_error: 2.9935e-05 - val_loss: 1.1677 - val_mean_absolute_error: 0.0054 - val_mean_absolute_percentage_error: 1.1677 - val_mean_squared_error: 4.5625e-05
# Epoch 30/30
# 2771/2771 [==============================] - 60s 22ms/step - loss: 0.8871 - mean_absolute_error: 0.0038 - mean_absolute_percentage_error: 0.8871 - mean_squared_error: 2.9223e-05 - val_loss: 0.7930 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 0.7930 - val_mean_squared_error: 2.3148e-05
#
# ======== Model: lstm_7 ========
# description: {'units': [256, 256, 32], 'dropout': None, 'loss': 'mean_absolute_percentage_error', 'batch_size': 512, 'epochs': 30, 'tic': 'ALL'}
#
# Epoch 1/30
# 174/174 [==============================] - 11s 49ms/step - loss: 29.4799 - mean_absolute_error: 0.1348 - mean_absolute_percentage_error: 29.4799 - mean_squared_error: 0.1055 - val_loss: 1.8594 - val_mean_absolute_error: 0.0081 - val_mean_absolute_percentage_error: 1.8594 - val_mean_squared_error: 1.2992e-04
# Epoch 2/30
# 174/174 [==============================] - 8s 45ms/step - loss: 2.8645 - mean_absolute_error: 0.0129 - mean_absolute_percentage_error: 2.8645 - mean_squared_error: 2.7743e-04 - val_loss: 2.6517 - val_mean_absolute_error: 0.0125 - val_mean_absolute_percentage_error: 2.6517 - val_mean_squared_error: 2.4321e-04
# Epoch 3/30
# 174/174 [==============================] - 8s 45ms/step - loss: 2.3658 - mean_absolute_error: 0.0106 - mean_absolute_percentage_error: 2.3658 - mean_squared_error: 1.8731e-04 - val_loss: 1.2914 - val_mean_absolute_error: 0.0054 - val_mean_absolute_percentage_error: 1.2914 - val_mean_squared_error: 6.5142e-05
# Epoch 4/30
# 174/174 [==============================] - 8s 45ms/step - loss: 2.1893 - mean_absolute_error: 0.0097 - mean_absolute_percentage_error: 2.1893 - mean_squared_error: 1.6874e-04 - val_loss: 1.2529 - val_mean_absolute_error: 0.0053 - val_mean_absolute_percentage_error: 1.2529 - val_mean_squared_error: 6.0058e-05
# Epoch 5/30
# 174/174 [==============================] - 8s 45ms/step - loss: 1.6868 - mean_absolute_error: 0.0074 - mean_absolute_percentage_error: 1.6868 - mean_squared_error: 9.4971e-05 - val_loss: 2.0583 - val_mean_absolute_error: 0.0095 - val_mean_absolute_percentage_error: 2.0583 - val_mean_squared_error: 1.2972e-04
# Epoch 6/30
# 174/174 [==============================] - 8s 45ms/step - loss: 1.7177 - mean_absolute_error: 0.0076 - mean_absolute_percentage_error: 1.7177 - mean_squared_error: 1.0146e-04 - val_loss: 1.9250 - val_mean_absolute_error: 0.0086 - val_mean_absolute_percentage_error: 1.9250 - val_mean_squared_error: 1.2038e-04
# Epoch 7/30
# 174/174 [==============================] - 8s 45ms/step - loss: 2.1571 - mean_absolute_error: 0.0097 - mean_absolute_percentage_error: 2.1571 - mean_squared_error: 1.5522e-04 - val_loss: 1.3845 - val_mean_absolute_error: 0.0056 - val_mean_absolute_percentage_error: 1.3845 - val_mean_squared_error: 6.2445e-05
# Epoch 8/30
# 174/174 [==============================] - 8s 45ms/step - loss: 1.9420 - mean_absolute_error: 0.0087 - mean_absolute_percentage_error: 1.9420 - mean_squared_error: 1.2447e-04 - val_loss: 1.1838 - val_mean_absolute_error: 0.0052 - val_mean_absolute_percentage_error: 1.1838 - val_mean_squared_error: 5.3040e-05
# Epoch 9/30
# 174/174 [==============================] - 8s 45ms/step - loss: 1.3421 - mean_absolute_error: 0.0058 - mean_absolute_percentage_error: 1.3421 - mean_squared_error: 6.0500e-05 - val_loss: 1.6072 - val_mean_absolute_error: 0.0072 - val_mean_absolute_percentage_error: 1.6072 - val_mean_squared_error: 7.7892e-05
# Epoch 10/30
# 174/174 [==============================] - 8s 45ms/step - loss: 1.7072 - mean_absolute_error: 0.0076 - mean_absolute_percentage_error: 1.7072 - mean_squared_error: 9.7294e-05 - val_loss: 0.9830 - val_mean_absolute_error: 0.0041 - val_mean_absolute_percentage_error: 0.9830 - val_mean_squared_error: 3.7514e-05
# Epoch 11/30
# 174/174 [==============================] - 8s 45ms/step - loss: 1.3480 - mean_absolute_error: 0.0059 - mean_absolute_percentage_error: 1.3480 - mean_squared_error: 6.2434e-05 - val_loss: 1.3876 - val_mean_absolute_error: 0.0061 - val_mean_absolute_percentage_error: 1.3876 - val_mean_squared_error: 6.0162e-05
# Epoch 12/30
# 174/174 [==============================] - 8s 45ms/step - loss: 1.7927 - mean_absolute_error: 0.0080 - mean_absolute_percentage_error: 1.7927 - mean_squared_error: 1.0598e-04 - val_loss: 2.2304 - val_mean_absolute_error: 0.0098 - val_mean_absolute_percentage_error: 2.2304 - val_mean_squared_error: 1.2706e-04
# Epoch 13/30
# 174/174 [==============================] - 8s 45ms/step - loss: 1.4804 - mean_absolute_error: 0.0065 - mean_absolute_percentage_error: 1.4804 - mean_squared_error: 7.2903e-05 - val_loss: 1.0142 - val_mean_absolute_error: 0.0043 - val_mean_absolute_percentage_error: 1.0142 - val_mean_squared_error: 3.8559e-05
# Epoch 14/30
# 174/174 [==============================] - 8s 45ms/step - loss: 1.2186 - mean_absolute_error: 0.0053 - mean_absolute_percentage_error: 1.2186 - mean_squared_error: 5.0376e-05 - val_loss: 2.4311 - val_mean_absolute_error: 0.0112 - val_mean_absolute_percentage_error: 2.4311 - val_mean_squared_error: 1.6963e-04
# Epoch 15/30
# 174/174 [==============================] - 8s 45ms/step - loss: 1.9370 - mean_absolute_error: 0.0088 - mean_absolute_percentage_error: 1.9370 - mean_squared_error: 1.1566e-04 - val_loss: 2.1037 - val_mean_absolute_error: 0.0091 - val_mean_absolute_percentage_error: 2.1037 - val_mean_squared_error: 1.1112e-04
# Epoch 16/30
# 174/174 [==============================] - 8s 45ms/step - loss: 1.4055 - mean_absolute_error: 0.0062 - mean_absolute_percentage_error: 1.4055 - mean_squared_error: 6.6523e-05 - val_loss: 1.4963 - val_mean_absolute_error: 0.0068 - val_mean_absolute_percentage_error: 1.4963 - val_mean_squared_error: 6.9336e-05
# Epoch 17/30
# 174/174 [==============================] - 8s 46ms/step - loss: 1.1841 - mean_absolute_error: 0.0052 - mean_absolute_percentage_error: 1.1841 - mean_squared_error: 4.8156e-05 - val_loss: 1.0504 - val_mean_absolute_error: 0.0043 - val_mean_absolute_percentage_error: 1.0504 - val_mean_squared_error: 3.8695e-05
# Epoch 18/30
# 174/174 [==============================] - 8s 46ms/step - loss: 1.3265 - mean_absolute_error: 0.0058 - mean_absolute_percentage_error: 1.3265 - mean_squared_error: 6.0809e-05 - val_loss: 1.0850 - val_mean_absolute_error: 0.0049 - val_mean_absolute_percentage_error: 1.0850 - val_mean_squared_error: 4.2497e-05
# Epoch 19/30
# 174/174 [==============================] - 8s 45ms/step - loss: 1.1566 - mean_absolute_error: 0.0050 - mean_absolute_percentage_error: 1.1566 - mean_squared_error: 4.6170e-05 - val_loss: 2.6001 - val_mean_absolute_error: 0.0116 - val_mean_absolute_percentage_error: 2.6001 - val_mean_squared_error: 1.6610e-04
# Epoch 20/30
# 174/174 [==============================] - 8s 46ms/step - loss: 1.7100 - mean_absolute_error: 0.0077 - mean_absolute_percentage_error: 1.7100 - mean_squared_error: 9.1646e-05 - val_loss: 0.9352 - val_mean_absolute_error: 0.0040 - val_mean_absolute_percentage_error: 0.9352 - val_mean_squared_error: 3.3326e-05
# Epoch 21/30
# 174/174 [==============================] - 8s 46ms/step - loss: 1.4482 - mean_absolute_error: 0.0064 - mean_absolute_percentage_error: 1.4482 - mean_squared_error: 7.2377e-05 - val_loss: 0.9409 - val_mean_absolute_error: 0.0040 - val_mean_absolute_percentage_error: 0.9409 - val_mean_squared_error: 3.2796e-05
# Epoch 22/30
# 174/174 [==============================] - 8s 45ms/step - loss: 1.0638 - mean_absolute_error: 0.0046 - mean_absolute_percentage_error: 1.0638 - mean_squared_error: 3.8936e-05 - val_loss: 0.8926 - val_mean_absolute_error: 0.0037 - val_mean_absolute_percentage_error: 0.8926 - val_mean_squared_error: 3.0912e-05
# Epoch 23/30
# 174/174 [==============================] - 8s 45ms/step - loss: 1.0619 - mean_absolute_error: 0.0046 - mean_absolute_percentage_error: 1.0619 - mean_squared_error: 3.9208e-05 - val_loss: 1.3620 - val_mean_absolute_error: 0.0057 - val_mean_absolute_percentage_error: 1.3620 - val_mean_squared_error: 5.2224e-05
# Epoch 24/30
#  72/174 [===========>..................] - ETA: 4s - loss: 1.1256 - mean_absolute_error: 0.0049 - mean_absolute_percentage_error: 1.1256 - mean_squared_error: 4.2153e-05

# %% [markdown]
# ### Learning Curves

# %%
def plot_history(model_name, history):
    plt.title(model_name)
    for k in history.history:
        plt.plot(history.history[k], label=k)
    plt.legend(loc='upper right')
    plt.yscale("log")
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
# %matplotlib inline

for model in model_list:
    plot_history(model['model_name'], model['history'])

# %% [markdown]
# ## Analysis and Prediction

# %% [markdown]
# ### Multiple Stocks Prediction

# %%
def retrain(x_train, y_train, model, batch_size=1, epochs=1):
    history = model.fit(x_train, y_train, batch_size = batch_size, epochs=epochs)
    return history

def inverse_transform_y(y_data, scaler, y_col_idx):
    a = np.zeros(shape=(len(y_data), scaler.scale_.shape[0]))
    a[:,y_col_idx]=y_data[:,0]
    return np.exp(scaler.inverse_transform(a)[:,0])

def predict(x, y_val, model):
    y = model.predict(x)
    mse = np.mean(((np.array(y).flatten() - np.array(y_val).flatten()) ** 2))
    return y, mse

# %%
def mse_evaluation(model):
    x_t, y_t = merge_tic(x_train_dict, y_train_dict)
    x_tt, y_tt = merge_tic(x_test_dict, y_test_dict)
    y_train_predict, train_mse = predict(x_t, y_t, model['model'])
    y_test_predict, test_mse = predict(x_tt, y_tt, model['model'])
    model['y_train_predict']=y_train_predict
    model['y_test_predict']=y_test_predict
    model['train_mse']= train_mse
    model['test_mse'] = test_mse
    print("model: {}\t train dataset mse: {}\t test dataset mse: {}\n".format(model['model_name'], train_mse, test_mse))

# %% [markdown]
# ### Single Stock Prediction

# %% [markdown]
# Select SPY as the sp index represent ticker, and trying to use model predict SPY ticker

# %% [markdown]
# #### Model Retrain with Single Stock Data

# %% [markdown]
# The above models already capture all tickers pattern. However, to fit one ticker better with above model, clone an model, and use SPY ticker training dataset to retrain the clone model.

# %%
x_train, y_train, x_test, y_test = x_train_dict['SPY'], y_train_dict['SPY'], x_test_dict['SPY'], y_test_dict['SPY']
model = tf.keras.models.clone_model(models['simple_lstm0'])
retrain(x_train, y_train, model, batch_size=16, epochs=5)

# %% [markdown]
# #### Prediction and Inverse Transform Result

# %%
y_train_predict, _ = predict(x_train, y_train, model)
y_test_predict, _ = predict(x_test, y_test, model)

train_predict = inverse_transform_y(y_train_predict, scalers['SPY'], y_col_idx=0)
train_val = inverse_transform_y(np.reshape(y_train, (y_train.shape[0], 1 )), scalers['SPY'], y_col_idx=0)
test_predict = inverse_transform_y(y_test_predict, scalers['SPY'], y_col_idx=0)
test_val = inverse_transform_y(np.reshape(y_test, (y_test.shape[0], 1 )), scalers['SPY'], y_col_idx=0)

# %% [markdown]
# #### Display A Continouos Data

# %%
train = SPY[input_width + shift - 1 : len(x_train) + input_width + shift - 1].copy()
train['predict']=train_predict
train['val']=train_val
valid = SPY[len(x_train) + input_width + shift - 1 :].copy()
valid['predict'] = test_predict
valid['val']=test_val

# %%
# %matplotlib inline

# Visualize the data
plt.figure(figsize=(16,6))
plt.title('Model')
plt.xlabel('Date', fontsize=10)
plt.ylabel('Close Price USD ($)', fontsize=10)
plt.plot(train['val'], label='train_val')
plt.plot(train['predict'], label='train_predict')
plt.plot(valid['val'], label='test_val')
plt.plot(valid['predict'], label='test_predict')
# plt.plot(train[['val','predict']])
# plt.plot(valid[['val','predict']])
# plt.legend(['Train', 'Train_Predict' 'Test', 'Test_Predict'], loc='lower right')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %% [markdown]
# ## Stock Trading

# %% [markdown]
# ### Trading Strategy

# %% [markdown]
# A simple strategy base on the prediction result:
# - condition1: if predict price lower than current price, hold cash
# - condition2: if predict price higher than or equal to current price, hold share

# %%
def trading(prev_price, real_price, predict_price):
    """
    Trading Logic
    """
    prev_portfolio = 1.0
    records = [prev_portfolio]
    for i in range(len(real_price)):
        if predict_price[i] > prev_price[i]:
            portfolio = (prev_portfolio / prev_price[i]) * real_price[i]
        else:
            portfolio = prev_portfolio
        prev_portfolio = portfolio
        records.append(prev_portfolio)
    return records

# %%
def gen_prev_price(begin_price, real_price):
    """
    Generate One Previous Value Point
    """
    prev_price=real_price.copy()[:-1]
    return np.insert(prev_price, 0, begin_price)

prev_val = gen_prev_price(train_val[-1], test_val)
records=trading(prev_val, test_val, test_predict)

# %% [markdown]
# ### Trading Performance Visualization

# %%
# %matplotlib inline

# Visualize the data
plt.figure(figsize=(16,6))
plt.title('Trading')
plt.xlabel('Date', fontsize=10)
plt.ylabel('Close Price USD ($)', fontsize=10)
plt.plot(test_val, label='test_val')

plt.plot(test_predict, label='test_predict')
plt.plot(records[1:]*prev_val, label='portfolio_return')
# plt.plot(train[['val','predict']])
# plt.plot(valid[['val','predict']])
# plt.legend(['Train', 'Train_Predict' 'Test', 'Test_Predict'], loc='lower right')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()
